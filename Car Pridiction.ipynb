# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
driver= webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.cars24.com/')

# %%
cross= driver.find_element_by_xpath('/html/body/div[1]/div[8]/div/div/h3/div/img')
cross.click()

# %%
view= driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[2]/div[2]/button')
view.click()

# %%
car_name=[]
model=[]
fuel=[]
down_pay=[]
drive_km=[]
no_of_owner=[]
last_price=[]

# %%
a= driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
for i in a:
    car_name.append(i.text)
    
m= driver.find_elements_by_xpath('//p[@class="cvakB"]')
for j in m:
    model.append(j.text)
    
dr= driver.find_elements_by_xpath('//span[@class="_3X7mV _2H07I"]')
for j in dr:
    down_pay.append(j.text)
    
f= driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
for j in f:
    fuel.append(j.text)
d= driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
for j in d:
    drive_km.append(j.text)
    
o= driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
for j in o:
    no_of_owner.append(j.text)


p= driver.find_elements_by_xpath('//div[@class="_7udZZ"]')
for j in p:
    last_price.append(j.text)

# %%
location=[]
for i in range(0,634):
    l= driver.find_elements_by_xpath('//div[@class="_1yX-_"]')
    for j in l:
        location.append(j.text)

# %%
df=pd.DataFrame({'Car Name':car_name, 'Model':model, 'Fule_Type':fuel, 'Driven_KM':drive_km,"No. of Owners":no_of_owner, "Location":location,"Last Price":last_price, "Down Pay":down_pay})
df
# Out:
#                     Car Name                        Model     Fule_Type  \
# 0         2019 Hyundai Verna       1.6 SX VTVT (O) Manual        Petrol
# 1            2019 KIA SELTOS        HTK 1.5 PETROL Manual        Petrol
# 2            2020 KIA SELTOS   HTK PLUS 1.5 PETROL Manual        Petrol
# 3          2019 Maruti Swift                   LXI Manual        Petrol
# 4        2020 MG HECTOR PLUS                    SHARP DCT        Petrol
# ..                       ...                          ...           ...
# 629   2019 Hyundai Grand i10  MAGNA 1.2 KAPPA VTVT Manual        Petrol
# 630        2017 Renault Kwid               1.0 RXL Manual        Petrol
# 631  2021 Maruti New Wagon-R               VXI 1.0 Manual        Petrol
# 632     2015 Maruti Alto 800               LXI CNG Manual  Petrol + CNG
# 633     2017 Mahindra TUV300                T10 MT Manual        Diesel
#
#      Driven_KM No. of Owners   Location  Last Price           Down Pay
# ...

# %%
df.to_csv('car_prediction.csv')

# %%
view= driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p/img')
view.click()

# %%
view= driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div/div[2]/div/div/ul/div[3]/li[2]/a/span')
view.click()

# %%
car_name1=[]
model1=[]
fuel1=[]
down_pay1=[]
drive_km1=[]
no_of_owner1=[]
last_price1=[]

# %%
a= driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
for i in a:
    car_name1.append(i.text)
    
m= driver.find_elements_by_xpath('//p[@class="cvakB"]')
for j in m:
    model1.append(j.text)
    
dr= driver.find_elements_by_xpath('//span[@class="_3X7mV _2H07I"]')
for j in dr:
    down_pay1.append(j.text)
    
f= driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
for j in f:
    fuel1.append(j.text)
d= driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
for j in d:
    drive_km1.append(j.text)
    
o= driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
for j in o:
    no_of_owner1.append(j.text)


p= driver.find_elements_by_xpath('//div[@class="_7udZZ"]')
for j in p:
    last_price1.append(j.text)

# %%
location1=[]
for i in range(0,145):
    l= driver.find_elements_by_xpath('//div[@class="_1yX-_"]')
    for j in l:
        location1.append(j.text)

# %%
print(len(car_name3),len(fuel3),len(drive_km3),len(no_of_owner3),len(last_price3))
# Out:
# 550 550 550 550 550

# %%
df1=pd.DataFrame({'Car Name':car_name1, 'Model':model1, 'Fule_Type':fuel1, 'Driven_KM':drive_km1,"No. of Owners":no_of_owner1, "Location":location1,"Last Price":last_price1, "Down Pay":down_pay1})
df1
# Out:
#                    Car Name                      Model Fule_Type  Driven_KM  \
# 0        2014 Toyota Innova  2.5 VX 8 STR BS IV Manual    Diesel  82,295 km
# 1      2014 Mahindra XUV500              W8 FWD Manual    Diesel  89,117 km
# 2        2015 Hyundai Creta     1.6 SX (O) CRDI Manual    Diesel  53,468 km
# 3           2020 KIA SELTOS         GTX+ 1.4 MT Manual    Petrol  27,802 km
# 4    2015 Hyundai Elite i20          SPORTZ 1.4 Manual    Diesel  93,680 km
# ..                      ...                        ...       ...        ...
# 140        2020 Maruti Alto                 VXI Manual    Petrol   6,618 km
# 141  2016 Hyundai Elite i20           MAGNA 1.2 Manual    Petrol  34,103 km
# 142        2020 Maruti Alto                 LXI Manual    Petrol  11,546 km
# 143        2018 Honda Amaze      1.2 EMT I VTEC Manual    Petrol  12,270 km
# 144    2021 Maruti S PRESSO            VXI PLUS Manual    Petrol  15,273 km
#
# ...

# %%
view= driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p/img')
view.click()

# %%
view= driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div/div[2]/div/div/ul/div[5]/li/a/span')
view.click()

# %%
car_name2=[]
model2=[]
fuel2=[]
down_pay2=[]
drive_km2=[]
no_of_owner2=[]
last_price2=[]

# %%
a= driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
for i in a:
    car_name2.append(i.text)
    
m= driver.find_elements_by_xpath('//p[@class="cvakB"]')
for j in m:
    model2.append(j.text)
    
dr= driver.find_elements_by_xpath('//span[@class="_3X7mV _2H07I"]')
for j in dr:
    down_pay2.append(j.text)
    
f= driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
for j in f:
    fuel2.append(j.text)
d= driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
for j in d:
    drive_km2.append(j.text)
    
o= driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
for j in o:
    no_of_owner2.append(j.text)


p= driver.find_elements_by_xpath('//div[@class="_7udZZ"]')
for j in p:
    last_price2.append(j.text)

# %%
location2=[]
for i in range(0,614):
    l= driver.find_elements_by_xpath('//div[@class="_1yX-_"]')
    for j in l:
        location2.append(j.text)

# %%
df2=pd.DataFrame({'Car Name':car_name2, 'Model':model2, 'Fule_Type':fuel2, 'Driven_KM':drive_km2,"No. of Owners":no_of_owner2, "Location":location2,"Last Price":last_price2, "Down Pay":down_pay2})
df2
# Out:
#                       Car Name                        Model     Fule_Type  \
# 0        2018 Ford Figo Aspire   1.2 TITANIUM PETROL Manual        Petrol
# 1               2019 MG HECTOR   SHARP DCT PETROL Automatic        Petrol
# 2             2013 Maruti Ritz                   VDI Manual        Diesel
# 3    2017 Toyota Corolla Altis                    GL Manual        Petrol
# 4            2014 Maruti Swift                   VXI Manual        Petrol
# ..                         ...                          ...           ...
# 609     2019 Hyundai Grand i10  MAGNA 1.2 KAPPA VTVT Manual        Petrol
# 610          2017 Renault Kwid               1.0 RXL Manual        Petrol
# 611    2021 Maruti New Wagon-R               VXI 1.0 Manual        Petrol
# 612       2015 Maruti Alto 800               LXI CNG Manual  Petrol + CNG
# 613       2017 Mahindra TUV300                T10 MT Manual        Diesel
#
#      Driven_KM No. of Owners   Location  Last Price           Down Pay
# ...

# %%
view= driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p/img')
view.click()

# %%
view= driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div/div[2]/ul/li[4]/a/span/img')
view.click()

# %%
car_name3=[]
model3=[]
fuel3=[]
down_pay3=[]
drive_km3=[]
no_of_owner3=[]
last_price3=[]

# %%
a= driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
for i in a:
    car_name3.append(i.text)
    
m= driver.find_elements_by_xpath('//p[@class="cvakB"]')
for j in m:
    model3.append(j.text)
    
dr= driver.find_elements_by_xpath('//span[@class="_3X7mV _2H07I"]')
for j in dr:
    down_pay3.append(j.text)
    
f= driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[3]')
for j in f:
    fuel3.append(j.text)
d= driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[1]')
for j in d:
    drive_km3.append(j.text)
    
o= driver.find_elements_by_xpath('//ul[@class="bVR0c"]/li[2]')
for j in o:
    no_of_owner3.append(j.text)


p= driver.find_elements_by_xpath('//div[@class="_7udZZ"]')
for j in p:
    last_price3.append(j.text)

# %%
location3=[]
for i in range(0,550):
    l= driver.find_elements_by_xpath('//div[@class="_1yX-_"]')
    for j in l:
        location3.append(j.text)

# %%
df3=pd.DataFrame({'Car Name':car_name3, 'Model':model3, 'Fule_Type':fuel3, 'Driven_KM':drive_km3,"No. of Owners":no_of_owner3, "Location":location3,"Last Price":last_price3, "Down Pay":down_pay3})
df3
# Out:
#                    Car Name                           Model     Fule_Type  \
# 0    2016 Hyundai Grand i10    SPORTZ 1.2 KAPPA VTVT Manual        Petrol
# 1          2013 Maruti Ritz                      ZXI Manual        Petrol
# 2      2017 Volkswagen Polo  COMFORTLINE 1.2L PETROL Manual        Petrol
# 3         2012 BMW 3 Series                  320D Automatic        Diesel
# 4      2016 Volkswagen Polo    TRENDLINE 1.2L PETROL Manual        Petrol
# ..                      ...                             ...           ...
# 545      2014 Maruti Ertiga                  VXI CNG Manual  Petrol + CNG
# 546         2018 Tata Tiago          XZ 1.2 REVOTRON Manual        Petrol
# 547     2014 Renault Duster                85 PS RXE Manual        Diesel
# 548        2013 Hyundai i20                 ASTA 1.2 Manual        Petrol
# 549      2019 Hyundai VENUE  1.0 TURBO GDI SX+ AT Automatic        Petrol
#
#      Driven_KM No. of Owners Location  Last Price           Down Pay
# ...

# %%
df_new = pd.concat([df,df1,df2,df3], ignore_index= True)
df_new
# Out:
#                  Car Name                           Model     Fule_Type  \
# 0      2019 Hyundai Verna          1.6 SX VTVT (O) Manual        Petrol
# 1         2019 KIA SELTOS           HTK 1.5 PETROL Manual        Petrol
# 2         2020 KIA SELTOS      HTK PLUS 1.5 PETROL Manual        Petrol
# 3       2019 Maruti Swift                      LXI Manual        Petrol
# 4     2020 MG HECTOR PLUS                       SHARP DCT        Petrol
# ...                   ...                             ...           ...
# 1938   2014 Maruti Ertiga                  VXI CNG Manual  Petrol + CNG
# 1939      2018 Tata Tiago          XZ 1.2 REVOTRON Manual        Petrol
# 1940  2014 Renault Duster                85 PS RXE Manual        Diesel
# 1941     2013 Hyundai i20                 ASTA 1.2 Manual        Petrol
# 1942   2019 Hyundai VENUE  1.0 TURBO GDI SX+ AT Automatic        Petrol
#
#       Driven_KM No. of Owners   Location  Last Price           Down Pay
# ...

# %%
df_new.to_csv('car_prediction.csv')

# %% [markdown]
# # Machine Learning Model

# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\NITIN GUPTA\\car_prediction.csv")
df
# Out:
#       Unnamed: 0             Car Name                           Model  \
# 0              0   2019 Hyundai Verna          1.6 SX VTVT (O) Manual
# 1              1      2019 KIA SELTOS           HTK 1.5 PETROL Manual
# 2              2      2020 KIA SELTOS      HTK PLUS 1.5 PETROL Manual
# 3              3    2019 Maruti Swift                      LXI Manual
# 4              4  2020 MG HECTOR PLUS                       SHARP DCT
# ...          ...                  ...                             ...
# 1938        1938   2014 Maruti Ertiga                  VXI CNG Manual
# 1939        1939      2018 Tata Tiago          XZ 1.2 REVOTRON Manual
# 1940        1940  2014 Renault Duster                85 PS RXE Manual
# 1941        1941     2013 Hyundai i20                 ASTA 1.2 Manual
# 1942        1942   2019 Hyundai VENUE  1.0 TURBO GDI SX+ AT Automatic
#
#          Fule_Type  Driven_KM No. of Owners   Location  Last Price  \
# ...

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# Car Name         0
# Model            0
# Fule_Type        0
# Driven_KM        0
# No. of Owners    0
# Location         0
# Last Price       0
# Down Pay         0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per above visualization no null value present.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1943 entries, 0 to 1942
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1943 non-null   int64
#  1   Car Name       1943 non-null   object
#  2   Model          1943 non-null   object
#  3   Fule_Type      1943 non-null   object
#  4   Driven_KM      1943 non-null   object
#  5   No. of Owners  1943 non-null   object
#  6   Location       1943 non-null   object
#  7   Last Price     1943 non-null   object
#  8   Down Pay       1943 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 136.7+ KB

# %% [markdown]
# # Checking Data Types

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Car Name         object
# Model            object
# Fule_Type        object
# Driven_KM        object
# No. of Owners    object
# Location         object
# Last Price       object
# Down Pay         object
# dtype: object

# %%
df['Last Price'].unique
# Out:
# <bound method Series.unique of 0        ₹9,81,699
# 1       ₹11,25,599
# 2       ₹10,97,499
# 3        ₹5,50,899
# 4       ₹19,25,699
#            ...
# 1938     ₹6,71,199
# 1939     ₹4,69,599
# 1940     ₹4,80,999
# 1941     ₹4,14,099
# 1942    ₹10,68,199
# Name: Last Price, Length: 1943, dtype: object>

# %%
df['Last Price'] = [x.strip('₹') for x in df['Last Price']]
df['Driven_KM'] = [x.strip(' km') for x in df['Driven_KM']]

# %%
df
# Out:
#       Unnamed: 0             Car Name                           Model  \
# 0              0   2019 Hyundai Verna          1.6 SX VTVT (O) Manual
# 1              1      2019 KIA SELTOS           HTK 1.5 PETROL Manual
# 2              2      2020 KIA SELTOS      HTK PLUS 1.5 PETROL Manual
# 3              3    2019 Maruti Swift                      LXI Manual
# 4              4  2020 MG HECTOR PLUS                       SHARP DCT
# ...          ...                  ...                             ...
# 1938        1938   2014 Maruti Ertiga                  VXI CNG Manual
# 1939        1939      2018 Tata Tiago          XZ 1.2 REVOTRON Manual
# 1940        1940  2014 Renault Duster                85 PS RXE Manual
# 1941        1941     2013 Hyundai i20                 ASTA 1.2 Manual
# 1942        1942   2019 Hyundai VENUE  1.0 TURBO GDI SX+ AT Automatic
#
#          Fule_Type Driven_KM No. of Owners   Location Last Price  \
# ...

# %%
df['Last Price'] = df['Last Price'].str.replace(',','')

# %%
df['Driven_KM'] = df['Driven_KM'].str.replace(',','')

# %%
df
# Out:
#       Unnamed: 0             Car Name                           Model  \
# 0              0   2019 Hyundai Verna          1.6 SX VTVT (O) Manual
# 1              1      2019 KIA SELTOS           HTK 1.5 PETROL Manual
# 2              2      2020 KIA SELTOS      HTK PLUS 1.5 PETROL Manual
# 3              3    2019 Maruti Swift                      LXI Manual
# 4              4  2020 MG HECTOR PLUS                       SHARP DCT
# ...          ...                  ...                             ...
# 1938        1938   2014 Maruti Ertiga                  VXI CNG Manual
# 1939        1939      2018 Tata Tiago          XZ 1.2 REVOTRON Manual
# 1940        1940  2014 Renault Duster                85 PS RXE Manual
# 1941        1941     2013 Hyundai i20                 ASTA 1.2 Manual
# 1942        1942   2019 Hyundai VENUE  1.0 TURBO GDI SX+ AT Automatic
#
#          Fule_Type Driven_KM No. of Owners   Location Last Price  \
# ...

# %%
df['Last Price'] = df['Last Price'].astype(float)

# %%
df['Driven_KM'] = df['Driven_KM'].astype(float)

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# Car Name          object
# Model             object
# Fule_Type         object
# Driven_KM        float64
# No. of Owners     object
# Location          object
# Last Price       float64
# Down Pay          object
# dtype: object

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
train=df
train
# Out:
#                  Car Name                           Model     Fule_Type  \
# 0      2019 Hyundai Verna          1.6 SX VTVT (O) Manual        Petrol
# 1         2019 KIA SELTOS           HTK 1.5 PETROL Manual        Petrol
# 2         2020 KIA SELTOS      HTK PLUS 1.5 PETROL Manual        Petrol
# 3       2019 Maruti Swift                      LXI Manual        Petrol
# 4     2020 MG HECTOR PLUS                       SHARP DCT        Petrol
# ...                   ...                             ...           ...
# 1938   2014 Maruti Ertiga                  VXI CNG Manual  Petrol + CNG
# 1939      2018 Tata Tiago          XZ 1.2 REVOTRON Manual        Petrol
# 1940  2014 Renault Duster                85 PS RXE Manual        Diesel
# 1941     2013 Hyundai i20                 ASTA 1.2 Manual        Petrol
# 1942   2019 Hyundai VENUE  1.0 TURBO GDI SX+ AT Automatic        Petrol
#
#       Driven_KM No. of Owners   Location  Last Price           Down Pay
# ...

# %%
#dividing Car name into Brand, Model, Model_Year
train['Model_year']=train['Car Name'].str.split(' ').str[0]
train['Brand']=train['Car Name'].str.split(' ').str[1]
train['Model']=train['Car Name'].str.split(' ').str[2].str.join("")
train
# Out:
#                  Car Name   Model     Fule_Type  Driven_KM No. of Owners  \
# 0      2019 Hyundai Verna   Verna        Petrol    80631.0     1st Owner
# 1         2019 KIA SELTOS  SELTOS        Petrol     9722.0     1st Owner
# 2         2020 KIA SELTOS  SELTOS        Petrol    12981.0     2nd Owner
# 3       2019 Maruti Swift   Swift        Petrol    17424.0     1st Owner
# 4     2020 MG HECTOR PLUS  HECTOR        Petrol     3313.0     1st Owner
# ...                   ...     ...           ...        ...           ...
# 1938   2014 Maruti Ertiga  Ertiga  Petrol + CNG    60621.0     1st Owner
# 1939      2018 Tata Tiago   Tiago        Petrol    27020.0     1st Owner
# 1940  2014 Renault Duster  Duster        Diesel    54808.0     1st Owner
# 1941     2013 Hyundai i20     i20        Petrol    59181.0     1st Owner
# 1942   2019 Hyundai VENUE   VENUE        Petrol    30833.0     2nd Owner
#
#        Location  Last Price           Down Pay Model_year    Brand
# ...

# %%
df = df.rename(columns = {'Last Price':'Last_Price'})
train= df
train
# Out:
#                  Car Name   Model     Fule_Type  Driven_KM No. of Owners  \
# 0      2019 Hyundai Verna   Verna        Petrol    80631.0     1st Owner
# 1         2019 KIA SELTOS  SELTOS        Petrol     9722.0     1st Owner
# 2         2020 KIA SELTOS  SELTOS        Petrol    12981.0     2nd Owner
# 3       2019 Maruti Swift   Swift        Petrol    17424.0     1st Owner
# 4     2020 MG HECTOR PLUS  HECTOR        Petrol     3313.0     1st Owner
# ...                   ...     ...           ...        ...           ...
# 1938   2014 Maruti Ertiga  Ertiga  Petrol + CNG    60621.0     1st Owner
# 1939      2018 Tata Tiago   Tiago        Petrol    27020.0     1st Owner
# 1940  2014 Renault Duster  Duster        Diesel    54808.0     1st Owner
# 1941     2013 Hyundai i20     i20        Petrol    59181.0     1st Owner
# 1942   2019 Hyundai VENUE   VENUE        Petrol    30833.0     2nd Owner
#
#        Location  Last_Price           Down Pay Model_year    Brand
# ...

# %%
train.nunique()
# Out:
# Car Name          353
# Model              91
# Fule_Type           3
# Driven_KM        1300
# No. of Owners       4
# Location            4
# Last Price       1207
# Down Pay            1
# Model_year         14
# Brand              19
# dtype: int64

# %%
sns.countplot(x='Car Name', data=df)
df['Car Name'].value_counts()
# Out:
# 2016 Maruti Vitara Brezza    44
# 2015 Maruti Swift            43
# 2018 Ford Ecosport           42
# 2014 Maruti Swift            40
# 2017 Maruti Vitara Brezza    37
#                              ..
# 2013 Hyundai Sonata           1
# 2020 Toyota URBAN CRUISER     1
# 2015 Maruti Ertiga            1
# 2015 Hyundai Verna            1
# 2014 Maruti Ertiga            1
# Name: Car Name, Length: 353, dtype: int64

# %% [markdown]
# As per avobe visualization there are 353 types of car names

# %%
sns.countplot(x='Model', data=df)
df['Model'].value_counts()
# Out:
# Swift       185
# Alto        161
# Baleno      136
# Vitara      121
# Ecosport    117
#            ...
# Sunny         1
# Accord        1
# Bolero        1
# Sonata        1
# MARAZZO       1
# Name: Model, Length: 91, dtype: int64

# %% [markdown]
# As per above visualization 91 type of model present.

# %%
train['Model_year'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per above visualization maximum cars from 2017 model.

# %%
train['No. of Owners'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per above visualization maximum cars are 1st owner few cars only 2nd and thirs owner

# %%
train['Fule_Type'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# As per above visualization maximum cars are fuel type Petrol and less are Petrol + CNG

# %%
train['Location'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The amximum care from New Delhi and Faridabad and less from Chandigarh

# %%
train['Down Pay'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# As above shows there is no down payment option for all cars

# %%
sns.distplot(train["Model_year"])
# Out:
# <AxesSubplot:xlabel='Model_year', ylabel='Density'>

# %% [markdown]
# Max cars from 2017

# %%
sns.distplot(train["Last_Price"])
# Out:
# <AxesSubplot:xlabel='Last_Price', ylabel='Density'>

# %%
sns.distplot(train["Driven_KM"])
# Out:
# <AxesSubplot:xlabel='Driven_KM', ylabel='Density'>

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(x='Driven_KM',y='Last_Price',data=train, hue='Fule_Type')
# Out:
# <AxesSubplot:xlabel='Driven_KM', ylabel='Last_Price'>

# %% [markdown]
# # Checking Outliers

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=train, x='Driven_KM')
# Out:
# <AxesSubplot:xlabel='Driven_KM'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=train, x='Last_Price')
# Out:
# <AxesSubplot:xlabel='Last_Price'>

# %% [markdown]
# As per above visualizaton outliers are present in data

# %% [markdown]
# # Removing Outliers

# %%
Q1 =train.quantile(0.25)
Q3 = train.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
train= train[((train.Driven_KM>= (Q1.Driven_KM - 1.5 * IQR.Driven_KM)) & (train.Driven_KM <= (Q3.Driven_KM + 1.5 * IQR.Driven_KM)))]
train= train[((train.Last_Price >= (Q1.Last_Price - 1.5 * IQR.Last_Price)) & (train.Last_Price <= (Q3.Last_Price + 1.5 * IQR.Last_Price)))]
train
# Out:
# Driven_KM      40534.0
# Last_Price    394400.0
# dtype: float64
#                  Car Name   Model     Fule_Type  Driven_KM No. of Owners  \
# 0      2019 Hyundai Verna   Verna        Petrol    80631.0     1st Owner
# 1         2019 KIA SELTOS  SELTOS        Petrol     9722.0     1st Owner
# 2         2020 KIA SELTOS  SELTOS        Petrol    12981.0     2nd Owner
# 3       2019 Maruti Swift   Swift        Petrol    17424.0     1st Owner
# 8        2013 Hyundai i10     i10        Petrol    71726.0     1st Owner
# ...                   ...     ...           ...        ...           ...
# 1938   2014 Maruti Ertiga  Ertiga  Petrol + CNG    60621.0     1st Owner
# 1939      2018 Tata Tiago   Tiago        Petrol    27020.0     1st Owner
# 1940  2014 Renault Duster  Duster        Diesel    54808.0     1st Owner
# 1941     2013 Hyundai i20     i20        Petrol    59181.0     1st Owner
# 1942   2019 Hyundai VENUE   VENUE        Petrol    30833.0     2nd Owner
#
# ...

# %%
df.describe()
# Out:
#            Driven_KM    Last_Price
# count    1943.000000  1.943000e+03
# mean    44335.866186  7.024192e+05
# std     29519.663092  3.783935e+05
# min        71.000000  1.996990e+05
# 25%     21637.000000  4.313990e+05
# 50%     38762.000000  5.935990e+05
# 75%     62171.000000  8.257990e+05
# max    167105.000000  2.583999e+06

# %%
train.corr()
# Out:
#             Driven_KM  Last_Price
# Driven_KM    1.000000   -0.130579
# Last_Price  -0.130579    1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(train.corr(),annot=True, linewidth=1, linecolor='red')
# Out:
# <AxesSubplot:>

# %%
# Dropping Car name as already has column Model, Version, Model-year
train.drop(['Car Name'], axis=1, inplace=True)

# %%
train
# Out:
#        Model     Fule_Type  Driven_KM No. of Owners   Location  Last_Price  \
# 0      Verna        Petrol    80631.0     1st Owner  New Delhi    981699.0
# 1     SELTOS        Petrol     9722.0     1st Owner  New Delhi   1125599.0
# 2     SELTOS        Petrol    12981.0     2nd Owner  New Delhi   1097499.0
# 3      Swift        Petrol    17424.0     1st Owner  New Delhi    550899.0
# 8        i10        Petrol    71726.0     1st Owner  New Delhi    245699.0
# ...      ...           ...        ...           ...        ...         ...
# 1938  Ertiga  Petrol + CNG    60621.0     1st Owner     Mumbai    671199.0
# 1939   Tiago        Petrol    27020.0     1st Owner     Mumbai    469599.0
# 1940  Duster        Diesel    54808.0     1st Owner     Mumbai    480999.0
# 1941     i20        Petrol    59181.0     1st Owner     Mumbai    414099.0
# 1942   VENUE        Petrol    30833.0     2nd Owner     Mumbai   1068199.0
#
#                Down Pay Model_year    Brand
# ...

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
for i in train.columns:
    if train[i].dtype == 'object':
        train[i]= enc.fit_transform(train[i].values.reshape(-1,1))

# %%
train.drop(['Down Pay'], axis=1, inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(train.corr(),annot=True, linewidth=1, linecolor='red')
# Out:
# <AxesSubplot:>

# %%
train.skew()
# Out:
# Model            0.292644
# Fule_Type       -0.270219
# Driven_KM        0.595099
# No. of Owners    2.059657
# Location        -0.214838
# Last_Price       0.847075
# Model_year      -0.370850
# Brand            0.269341
# dtype: float64

# %% [markdown]
# As pr above data there is no skewness in data skewness present in object data type

# %% [markdown]
# # Splitting Featur and Target

# %%
x=train.drop(columns='Last_Price',axis=1)
y=train[['Last_Price']]

# %% [markdown]
# # Scaling using Min_Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

mn=MinMaxScaler()
x=mn.fit_transform(x)

# %% [markdown]
# # Importing Model

# %%
import sklearn
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
ne = KNeighborsRegressor(n_neighbors=2)
dt = DecisionTreeRegressor()
rf= RandomForestRegressor(n_estimators=100, random_state=42)
ab= AdaBoostRegressor()
rd= Ridge()
mod = [ne, dt, rf, ab, rd]
mod

# %%
for j in mod:
    for i in range(0,100):
        xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size= 0.22, random_state=i)
        j.fit(xtrain,ytrain)
        pred_train = j.predict(xtrain)
        pred_test= j.predict(xtest)

        print(f"For Model {j} At random state {i}, the training accuracy is: {r2_score(ytrain,pred_train)}")
        print(f"For Model {j} At random state {i}, the testing accuracy is: {r2_score(ytest,pred_test)}")
        print('\n')
# Out:
# For Model KNeighborsRegressor(n_neighbors=2) At random state 0, the training accuracy is: 0.8564288341983813
# For Model KNeighborsRegressor(n_neighbors=2) At random state 0, the testing accuracy is: 0.47882500226960334
#
#
# For Model KNeighborsRegressor(n_neighbors=2) At random state 1, the training accuracy is: 0.841962398546351
# For Model KNeighborsRegressor(n_neighbors=2) At random state 1, the testing accuracy is: 0.4678448399092143
#
#
# For Model KNeighborsRegressor(n_neighbors=2) At random state 2, the training accuracy is: 0.8453595673447165
# For Model KNeighborsRegressor(n_neighbors=2) At random state 2, the testing accuracy is: 0.515792523911208
#
#
# For Model KNeighborsRegressor(n_neighbors=2) At random state 3, the training accuracy is: 0.850863102877743
# For Model KNeighborsRegressor(n_neighbors=2) At random state 3, the testing accuracy is: 0.4686535160389622
#
#
# ...

# %% [markdown]
# As per above visualization we found model Random Forest Regressor is best at random state 11

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size= 0.22, random_state=11)
predrf_train = rf.predict(xtrain)
predrf_test= rf.predict(xtest)

print("Mean Squared error", mean_squared_error(ytest,predrf_test))
print("Mean Absolute Error", mean_absolute_error(ytest,predrf_test))
# Out:
# Mean Squared error 1631959199.740681
# Mean Absolute Error 24516.03607692308

# %%
print(r2_score(ytest,predrf_test))
# Out:
# 0.9723555247030031

# %% [markdown]
# # Using Grid Search CV Best Parameter

# %%
from sklearn.model_selection import GridSearchCV

model = RandomForestRegressor()
param_grid = {'n_estimators': [10,20,50,100],"max_features" : ["auto", "sqrt", "log2"],"min_samples_split": [2,4,8],"bootstrap": [True, False]}
xg_grid = GridSearchCV(estimator = model, param_grid = param_grid)
print(xg_grid)
xg_grid.fit(xtrain, ytrain)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 50, 100]})
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 50, 100]})

# %%
print(xg_grid.best_score_)
print(xg_grid.best_estimator_)
print(xg_grid.best_params_)
# Out:
# 0.8688376362517243
# RandomForestRegressor(max_features='auto')
# {'bootstrap': True, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 100}

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size= 0.22, random_state=11)
RFR = RandomForestRegressor(n_estimators=100,bootstrap=True,max_features='auto', min_samples_split=2)
RFR.fit(xtrain,ytrain)
pred_train =RFR.predict(xtrain)
pred_test= RFR.predict(xtest)
print("Mean Squared error", mean_squared_error(ytest,pred_test))
print("Mean Absolute Error", mean_absolute_error(ytest,pred_test))
# Out:
# Mean Squared error 4376324277.830162
# Mean Absolute Error 43488.599256410256

# %%
print(r2_score(ytest,pred_test))
# Out:
# 0.925867516535127

# %% [markdown]
# # Cross Validation of the Model

# %%
train_accuracy = r2_score(ytrain,pred_train)
test_accuracy =r2_score(ytest,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score =cross_val_score(RFR,x,y,cv=j)
    cv_mean = cv_score.mean()
    print(f"At cross val  {j} the cv score  is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross val  2 the cv score  is 0.8411565395845962 and accuracy score for training is 0.9851398998016849 and accuracy for testing is 0.925867516535127
#
#
# At cross val  3 the cv score  is 0.8637730735486283 and accuracy score for training is 0.9851398998016849 and accuracy for testing is 0.925867516535127
#
#
# At cross val  4 the cv score  is 0.874426876011947 and accuracy score for training is 0.9851398998016849 and accuracy for testing is 0.925867516535127
#
#
# At cross val  5 the cv score  is 0.8736686210516529 and accuracy score for training is 0.9851398998016849 and accuracy for testing is 0.925867516535127
#
#
# At cross val  6 the cv score  is 0.8809501954107585 and accuracy score for training is 0.9851398998016849 and accuracy for testing is 0.925867516535127
#
#
# At cross val  7 the cv score  is 0.8833764934450495 and accuracy score for training is 0.9851398998016849 and accuracy for testing is 0.925867516535127
#
#
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(x= ytest, y =pred_test, color= "maroon")
plt.plot(ytest,ytest, color='b')
plt.xlabel('Actual Charges', fontsize= 14)
plt.ylabel("Predicted Charges", fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), None)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [156], in <cell line: 3>()
#       1 plt.figure(figsize=(8,6))
#       2 plt.scatter(x= ytest, y =pred_test, color= "maroon")
# ----> 3 plt.plot(ytest,ytest, color='b')
# ...

# %% [markdown]
# # Saving Model

# %%
import pickle
filename = 'car.pkl'
pickle.dump(RFR,open(filename, 'wb'))

# %% [markdown]
# # Conclusion

# %%
loaded_model = pickle.load(open('car.pkl', 'rb'))
result = loaded_model.score(xtest,ytest)
print(result)
# Out:
# 0.925867516535127

# %%
conclusion = pd.DataFrame([loaded_model.predict(xtest)[:],pred_test[:]],index=["Predicted", "Original"])

# %%
conclusion
# Out:
#                 0          1         2         3         4          5    \
# Predicted  483349.0  634162.24  610026.0  419295.0  569154.8  375429.95
# Original   483349.0  634162.24  610026.0  419295.0  569154.8  375429.95
#
#                 6          7          8          9    ...       380       381  \
# Predicted  405738.0  369173.76  550095.24  655327.92  ...  879954.0  653507.0
# Original   405738.0  369173.76  550095.24  655327.92  ...  879954.0  653507.0
#
#                 382       383       384       385       386       387  \
# Predicted  449149.0  539125.0  742361.0  454610.0  415588.5  459260.0
# Original   449149.0  539125.0  742361.0  454610.0  415588.5  459260.0
#
#                 388        389
# Predicted  773631.0  484112.49
# Original   773631.0  484112.49
#
# [2 rows x 390 columns]
