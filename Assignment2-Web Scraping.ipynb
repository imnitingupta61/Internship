# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
#Let first connect to the web driver
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Open up Naukri.com website
driver.get('http://www.naukri.com/')

# %%
#finding element for job search bar
search_field_designation = driver.find_element_by_class_name('suggestor-input') #job search bar
search_field_designation.send_keys('Data Scientist')

# %%
#Entering location delhi in location search bar
search_field_loc = driver.find_element_by_class_name('suggestor-input')
search_field_loc.send_keys('Bangalore')  #this is not working as same class for both designation and location

#we need to use Absolute xpath

# %%
search_field_location = driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[3]/div/div/div/input')
search_field_location.send_keys('Bangalore')

# %%
#Click on search button

search_button = driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]')
search_button.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tag = driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in title_tag:
    job_title.append(i.text)
job_title[0:10]
# Out:
# ['Data Scientist: Artificial Intelligence',
#  'Staff Data Scientist',
#  'Senior Data Scientist',
#  'Cognitive/AI Senior Data Scientist',
#  'Lead - Data Scientist',
#  'Data Scientist',
#  'Senior Associate - Data Scientist',
#  'Rolls-Royce Data Labs : Data Scientist',
#  'Data Scientist',
#  'Staff Data Scientist']

# %%
company_tag = driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
for i in company_tag:
    company_name.append(i.text)
company_name[0:10]
# Out:
# ['IBM',
#  'Walmart',
#  'Walmart',
#  'IBM',
#  'Applied Materials',
#  'Applied Materials',
#  'Affine',
#  'Rolls Royce',
#  'Applied Materials',
#  'Walmart']

# %%
loc_tag = driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span")
for i in loc_tag:
    job_location.append(i.text)
job_location[0:10]
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Remote',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
exp_tag = driver.find_elements_by_xpath("//li[@class ='fleft grey-text br2 placeHolderLi experience']/span")
for i in exp_tag:
    experience_required.append(i.text)
experience_required[0:10]
# Out:
# ['6-11 Yrs',
#  '4-8 Yrs',
#  '5-10 Yrs',
#  '4-8 Yrs',
#  '10-15 Yrs',
#  '0-3 Yrs',
#  '2-4 Yrs',
#  '3-5 Yrs',
#  '7-10 Yrs',
#  '4-8 Yrs']

# %%
import pandas as pd
df = pd.DataFrame({"Job_Title":job_title, "CompanY_Name":company_name, "Job_Location":job_location, "Expirence_Required":experience_required})
df[0:10]
# Out:
#                                  Job_Title       CompanY_Name  \
# 0  Data Scientist: Artificial Intelligence                IBM
# 1                     Staff Data Scientist            Walmart
# 2                    Senior Data Scientist            Walmart
# 3       Cognitive/AI Senior Data Scientist                IBM
# 4                    Lead - Data Scientist  Applied Materials
# 5                           Data Scientist  Applied Materials
# 6        Senior Associate - Data Scientist             Affine
# 7   Rolls-Royce Data Labs : Data Scientist        Rolls Royce
# 8                           Data Scientist  Applied Materials
# 9                     Staff Data Scientist            Walmart
#
#           Job_Location Expirence_Required
# 0  Bangalore/Bengaluru           6-11 Yrs
# 1  Bangalore/Bengaluru            4-8 Yrs
# 2  Bangalore/Bengaluru           5-10 Yrs
# 3  Bangalore/Bengaluru            4-8 Yrs
# 4  Bangalore/Bengaluru          10-15 Yrs
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('http://www.naukri.com/')

# %%
search_field_designation = driver.find_element_by_class_name('suggestor-input') #job search bar
search_field_designation.send_keys('Data Scientist')

# %%
search_field_location = driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[3]/div/div/div/input')
search_field_location.send_keys('Bangalore')

# %%
search_button = driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]')
search_button.click()

# %%
job_title=[]
job_location=[]
company_name=[]

# %%
title_tag = driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in title_tag:
    job_title.append(i.text)
job_title[0:10]
# Out:
# ['Data Scientist: Artificial Intelligence',
#  'Staff Data Scientist',
#  'Senior Data Scientist',
#  'Cognitive/AI Senior Data Scientist',
#  'Lead - Data Scientist',
#  'Data Scientist',
#  'Senior Associate - Data Scientist',
#  'Rolls-Royce Data Labs : Data Scientist',
#  'Data Scientist',
#  'Staff Data Scientist']

# %%
loc_tag = driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span")
for i in loc_tag:
    job_location.append(i.text)
job_location[0:10]
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Remote',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
company_tag = driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
for i in company_tag:
    company_name.append(i.text)
company_name[0:10]
# Out:
# ['IBM',
#  'Walmart',
#  'Walmart',
#  'IBM',
#  'Applied Materials',
#  'Applied Materials',
#  'Affine',
#  'Rolls Royce',
#  'Applied Materials',
#  'Walmart']

# %%
import pandas as pd
df = pd.DataFrame({"Job_Title":job_title, "Job_Location":job_location, "CompanY_Name":company_name})
df[0:10]
# Out:
#                                  Job_Title         Job_Location  \
# 0  Data Scientist: Artificial Intelligence  Bangalore/Bengaluru
# 1                     Staff Data Scientist  Bangalore/Bengaluru
# 2                    Senior Data Scientist  Bangalore/Bengaluru
# 3       Cognitive/AI Senior Data Scientist  Bangalore/Bengaluru
# 4                    Lead - Data Scientist  Bangalore/Bengaluru
# 5                           Data Scientist  Bangalore/Bengaluru
# 6        Senior Associate - Data Scientist               Remote
# 7   Rolls-Royce Data Labs : Data Scientist  Bangalore/Bengaluru
# 8                           Data Scientist  Bangalore/Bengaluru
# 9                     Staff Data Scientist  Bangalore/Bengaluru
#
#         CompanY_Name
# 0                IBM
# 1            Walmart
# 2            Walmart
# 3                IBM
# 4  Applied Materials
# 5  Applied Materials
# 6             Affine
# 7        Rolls Royce
# 8  Applied Materials
# 9            Walmart

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage as shown below:

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('http://www.naukri.com/')

# %%
search_field_designation = driver.find_element_by_class_name('suggestor-input') #job search bar
search_field_designation.send_keys('Data Scientist')

search_button = driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]')
search_button.click()

# %%
search_salary_filter = driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[5]/div[2]/div[2]/label/i")
search_salary_filter.click()
time.sleep(5)

# %%
search_loc_filter = driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[5]/div[2]/div[3]/label/i")
search_loc_filter.click()
time.sleep(5)

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tag = driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in title_tag:
    job_title.append(i.text)
job_title[0:10]
# Out:
# ['Data Scientist',
#  'Associate Data Scientist',
#  'Associate Scientist - Data Engineering',
#  'Data Scientist (freelance)',
#  'Data Scientist/ Machine Learning, 2022 Passout Can also apply',
#  'Hiring For Data Analyst and Data Scientist For Gurgaon Location',
#  'Data Scientist',
#  'Data Scientist',
#  'Hiring For Senior Data Scientist-Noida',
#  'Senior Data Scientist']

# %%
loc_tag = driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span")
for i in loc_tag:
    job_location.append(i.text)
job_location[0:10]
# Out:
# ['Noida, Bangalore/Bengaluru',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'New Delhi, Delhi',
#  'Hyderabad/Secunderabad, Pune, Chennai, Delhi / NCR, Vadodara, Mumbai (All Areas)',
#  'Noida, Gurgaon/Gurugram, Delhi / NCR',
#  'Gurgaon, Bengaluru',
#  'New Delhi',
#  'Noida, Greater Noida, Delhi / NCR',
#  'Delhi']

# %%
company_tag = driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
for i in company_tag:
    company_name.append(i.text)
company_name[0:10]
# Out:
# ['Ashkom Media India Private Limited',
#  'Optum',
#  'AXA Technology Services India Pvt. Ltd',
#  '2Coms',
#  'Creative Hands HR Consultancy',
#  'Shadow Placements',
#  'BlackBuck',
#  'Boston Consulting Group',
#  'Lumiq.ai',
#  'iNICU']

# %%
exp_tag = driver.find_elements_by_xpath("//li[@class ='fleft grey-text br2 placeHolderLi experience']/span")
for i in exp_tag:
    experience_required.append(i.text)
experience_required[0:10]
# Out:
# ['3-6 Yrs',
#  '1-5 Yrs',
#  '2-5 Yrs',
#  '2-7 Yrs',
#  '0-4 Yrs',
#  '3-7 Yrs',
#  '3-7 Yrs',
#  '2-5 Yrs',
#  '2-6 Yrs',
#  '1-5 Yrs']

# %%
import pandas as pd
df = pd.DataFrame({"Job_Title":job_title, "CompanY_Name":company_name, "Job_Location":job_location, "Expirence_Required":experience_required})
df[0:10]
# Out:
#                                            Job_Title  \
# 0                                     Data Scientist
# 1                           Associate Data Scientist
# 2             Associate Scientist - Data Engineering
# 3                         Data Scientist (freelance)
# 4  Data Scientist/ Machine Learning, 2022 Passout...
# 5  Hiring For Data Analyst and Data Scientist For...
# 6                                     Data Scientist
# 7                                     Data Scientist
# 8             Hiring For Senior Data Scientist-Noida
# 9                              Senior Data Scientist
#
#                              CompanY_Name  \
# 0      Ashkom Media India Private Limited
# 1                                   Optum
# 2  AXA Technology Services India Pvt. Ltd
# 3                                   2Coms
# 4           Creative Hands HR Consultancy
# 5                       Shadow Placements
# 6                               BlackBuck
# ...

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')

# %%
cross_filter = driver.find_element_by_xpath("/html/body/div[2]/div/div/button")
cross_filter.click()
time.sleep(5)

# %%
search_field_item = driver.find_element_by_class_name("_3704LK") 
search_field_item.send_keys('Sunglasses')

# %%
item_filter = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
item_filter.click()

# %%
t_list=[]
for i in range(0,3):
    title_tag = driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
    for i in title_tag:
        t_list.append(i.text)
        
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")

    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
    time.sleep(5)
tlist=t_list[0:100]
tlist
# Out:
# ['ROZZETTA CRAFT',
#  'AISLIN',
#  'Fastrack',
#  'Fastrack',
#  'Elligator',
#  'SUNBEE',
#  'PIRASO',
#  'ROYAL SON',
#  'DAHAAZIL',
#  'Fastrack',
#  'Mi',
#  'ROYAL SON',
#  'PIRASO',
#  'Lee Topper',
#  'Mi',
#  'agera',
#  'PIRASO',
#  'New Specs',
#  'Fastrack',
#  'VINCENT CHASE',
#  'HIPPON',
#  'PIRASO',
#  'SRPM',
#  'GANSTA',
#  'SUNBEE',
#  'hipe',
#  'PIRASO',
#  'Ray-Ban',
#  'PIRASO',
#  'SHAAH COLLECTIONS',
#  'Elligator',
#  'Resist',
#  'ROZZETTA CRAFT',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'GANSTA',
#  'Mi',
#  'kingsunglasses',
#  'DEIXELS',
#  'Ray-Ban',
#  'Fastrack',
#  'New Specs',
#  'PHENOMENAL',
#  'VINCENT CHASE',
#  'Lee Topper',
#  'ROYAL SON',
#  'Poloport',
#  'VINCENT CHASE',
#  'VINCENT CHASE',
#  'ROZZETTA CRAFT',
#  'SRPM',
#  'ROZZETTA CRAFT',
#  'VINCENT CHASE',
#  'PIRASO',
#  'Fastrack',
#  'Ray-Ban',
#  'New Specs',
#  'Fastrack',
#  'GANSTA',
#  'ROYAL SON',
#  'Fastrack',
#  'kingsunglasses',
#  'PHENOMENAL',
#  'john jacobs',
# ...

# %%
item_filter = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
item_filter.click()

# %%
pr_list=[]
for i in range(0,3):
    title_tag = driver.find_elements_by_xpath("//a[@class='IRpwTa']")
    for i in title_tag:
        pr_list.append(i.text)
        
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")

    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
    time.sleep(5)
prlist= pr_list[0:100]
prlist
# Out:
# ['UV Protection Aviator Sunglasses (62)',
#  'UV Protection, Riding Glasses, Toughened Glass Lens, Gr...',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection, Polarized Wayfarer Sunglasses (Free Size...',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Oval Sunglasses (49)',
#  'UV Protection, Night Vision, Riding Glasses Wayfarer, W...',
#  'UV Protection Shield Sunglasses (Free Size)',
#  'Polarized Aviator Sunglasses (Free Size)',
#  'Polarized, UV Protection Wrap-around Sunglasses (62)',
#  'UV Protection Aviator Sunglasses (54)',
#  'Riding Glasses Wrap-around Sunglasses (Free Size)',
#  'Polarized Wayfarer Sunglasses (Free Size)',
#  'Gradient Aviator Sunglasses (55)',
#  'UV Protection Aviator Sunglasses (58)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (Free Size)',
# ...

# %%
item_filter = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
item_filter.click()

# %%
p_list=[]
for i in range(0,3):
    price_tag = driver.find_elements_by_xpath("//div[@class='_30jeq3']")
    for i in price_tag:
        p_list.append(i.text)
        
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")

    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
    time.sleep(5)
plist = p_list[0:100]
plist
# Out:
# ['₹649',
#  '₹6,038',
#  '₹719',
#  '₹355',
#  '₹283',
#  '₹575',
#  '₹236',
#  '₹799',
#  '₹219',
#  '₹809',
#  '₹299',
#  '₹4,489',
#  '₹764',
#  '₹908',
#  '₹224',
#  '₹999',
#  '₹639',
#  '₹349',
#  '₹269',
#  '₹948',
#  '₹249',
#  '₹225',
#  '₹181',
#  '₹7,669',
#  '₹259',
#  '₹208',
#  '₹224',
#  '₹699',
#  '₹280',
#  '₹195',
#  '₹333',
#  '₹199',
#  '₹647',
#  '₹399',
#  '₹499',
#  '₹295',
#  '₹209',
#  '₹229',
#  '₹1,009',
#  '₹899',
#  '₹410',
#  '₹276',
#  '₹399',
#  '₹649',
#  '₹214',
#  '₹315',
#  '₹649',
#  '₹649',
#  '₹899',
#  '₹249',
#  '₹639',
#  '₹499',
#  '₹189',
#  '₹329',
#  '₹284',
#  '₹3,349',
#  '₹749',
#  '₹349',
#  '₹719',
#  '₹799',
#  '₹639',
#  '₹246',
#  '₹179',
#  '₹2,500',
#  '₹399',
#  '₹498',
#  '₹229',
#  '₹3,909',
#  '₹699',
#  '₹649',
#  '₹379',
#  '₹8,709',
#  '₹369',
#  '₹329',
#  '₹260',
#  '₹498',
#  '₹358',
#  '₹223',
#  '₹245',
#  '₹5,389',
#  '₹575',
#  '₹329',
#  '₹1,039',
#  '₹649',
#  '₹366',
#  '₹189',
#  '₹349',
#  '₹649',
# ...

# %%
item_filter = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
item_filter.click()

# %%
d_list=[]
for i in range(0,3):
    discount_tag = driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
    for i in discount_tag:
        d_list.append(i.text)
        
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")

    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
    time.sleep(5)
dlist=d_list[0:100]
dlist
# Out:
# ['30% off',
#  '60% off',
#  '20% off',
#  '28% off',
#  '85% off',
#  '78% off',
#  '85% off',
#  '65% off',
#  '78% off',
#  '10% off',
#  '24% off',
#  '50% off',
#  '85% off',
#  '88% off',
#  '23% off',
#  '37% off',
#  '86% off',
#  '89% off',
#  '20% off',
#  '52% off',
#  '81% off',
#  '85% off',
#  '80% off',
#  '85% off',
#  '80% off',
#  '83% off',
#  '85% off',
#  '80% off',
#  '89% off',
#  '88% off',
#  '83% off',
#  '20% off',
#  '80% off',
#  '75% off',
#  '28% off',
#  '84% off',
#  '15% off',
#  '82% off',
#  '80% off',
#  '67% off',
#  '23% off',
#  '86% off',
#  '68% off',
#  '67% off',
#  '88% off',
#  '73% off',
#  '87% off',
#  '67% off',
#  '55% off',
#  '74% off',
#  '75% off',
#  '75% off',
#  '70% off',
#  '78% off',
#  '20% off',
#  '40% off',
#  '83% off',
#  '20% off',
#  '85% off',
#  '60% off',
#  '20% off',
#  '79% off',
#  '81% off',
#  '50% off',
#  '85% off',
#  '77% off',
#  '81% off',
#  '30% off',
#  '22% off',
#  '67% off',
#  '86% off',
# ...

# %%
print(len(tlist),len(prlist),len(plist),len(dlist))
# Out:
# 100 100 100 100

# %%
import pandas as pd
df = pd.DataFrame({"Brand":tlist, "Product Description":prlist, "Price":plist, "Discount":dlist})
df
# Out:
#              Brand                                Product Description   Price  \
# 0   ROZZETTA CRAFT              UV Protection Aviator Sunglasses (62)    ₹649
# 1           AISLIN  UV Protection, Riding Glasses, Toughened Glass...  ₹6,038
# 2         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)    ₹719
# 3         Fastrack   UV Protection Rectangular Sunglasses (Free Size)    ₹355
# 4        Elligator                UV Protection Round Sunglasses (54)    ₹283
# ..             ...                                                ...     ...
# 95          GANSTA             UV Protection Wayfarer Sunglasses (53)    ₹284
# 96       Elligator                UV Protection Round Sunglasses (53)    ₹224
# 97       Elligator                 UV Protection Oval Sunglasses (57)    ₹244
# 98        Roadster  UV Protection, Gradient Retro Square Sunglasse...    ₹649
# 99  ROZZETTA CRAFT         UV Protection Round Sunglasses (Free Size)    ₹499
#
#    Discount
# 0   30% off
# ...

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb-includes- earpods-power- adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKC TSVZAXUHGREPBFGI&marketplace.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb-includes- earpods-power- adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKC TSVZAXUHGREPBFGI&marketplace.')

# %%
click_on = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div/div/div[5]/div/a/div/span")
click_on.click()

# %%
rate_list=[]
review_list=[]
f_review_list=[]

#for i in range(0,8):
#    r_title = driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
#    for i in r_title:
#        rate_list.append(i.text)
#    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")#scraping the list of buttons from the page
#    try:
#        driver.get(nxt_button[1].get_attribute('href'))#getting the link from the list for next page
#    except:
 #       driver.get(nxt_button[0].get_attribute('href'))
    
#rate_list
urls=[]
for i in range(0,10):
    url_1 = driver.find_elements_by_xpath("//a[@class='ge-49M _2Kfbh8']")
    for i in url_1:
        urls.append(i.get_attribute('href'))

    url_2 = driver.find_elements_by_xpath("//a[@class='ge-49M']")
    for i in url_2:
        urls.append(i.get_attribute('href'))
        time.sleep(4)
urls
# Out:
# ['https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGR3IXQLM&marketplace=FLIPKART&page=1',
#  'https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGR3IXQLM&marketplace=FLIPKART&page=2',
#  'https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGR3IXQLM&marketplace=FLIPKART&page=3',
#  'https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGR3IXQLM&marketplace=FLIPKART&page=4',
# ...

# %%
len(rate_list)
# Out:
# 78

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com andsearch for “sneakers” in the search field.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')

# %%
cross_filter = driver.find_element_by_xpath("/html/body/div[2]/div/div/button")
cross_filter.click()

# %%
search_field_item = driver.find_element_by_class_name("_3704LK") 
search_field_item.send_keys('Shoes')

# %%
item_filter = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
item_filter.click()

# %%
s_list=[]
for i in range(0,3):
    title_tag = driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
    for i in title_tag:
        s_list.append(i.text)
        
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")

    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
    time.sleep(5)
slist=s_list[0:100]
slist
# Out:
# ['NIKE',
#  'NIKE',
#  'BRUTON',
#  'density',
#  'RED TAPE',
#  'ADIDAS',
#  'CAMPUS',
#  'RED TAPE',
#  'BIRDE',
#  'density',
#  'ASIAN',
#  'PUMA',
#  'HOTSTYLE',
#  'BRUTON',
#  'BRUTON',
#  "K ' Footlance",
#  'BIRDE',
#  'HOTSTYLE',
#  'Layasa',
#  'ASIAN',
#  'CAMPUS',
#  'REEBOK',
#  'ASIAN',
#  'ASIAN',
#  'REEBOK CLASSICS',
#  'BERSACHE',
#  'ASIAN',
#  'ADIDAS',
#  'ASIAN',
#  'BIRDE',
#  'aadi',
#  'ADIDAS',
#  'SCATCHITE',
#  'Layasa',
#  'aadi',
#  'ADIDAS',
#  'HOTSTYLE',
#  'Deals4you',
#  'TR',
#  'DUNKASTON',
#  'D-SNEAKERZ',
#  'Layasa',
#  'CAMPUS',
#  'ADIDAS',
#  'Axter',
#  'Paragon',
#  'ADIDAS',
#  'REEBOK',
#  'Kraasa',
#  'ASIAN',
#  'BIRDE',
#  'REEBOK',
#  'SWIGGY',
#  'RED CHIEF',
#  'Robbie jones',
#  'PUMA',
#  'AMICO',
#  'HOTSTYLE',
#  'bluemaker',
#  'REEBOK',
#  'ASIAN',
#  'RED TAPE',
#  'REEBOK',
#  'REEBOK',
#  'ASIAN',
#  'Kraasa',
#  'ADIDAS',
#  'REEBOK',
#  'ADIDAS',
#  'ASIAN',
#  "K ' Footlance",
#  'PUMA',
#  'ASIAN',
#  'bluemaker',
# ...

# %%
item_filter = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
item_filter.click()

# %%
sr_list=[]
for i in range(0,3):
    title_tag = driver.find_elements_by_xpath("//a[@class='IRpwTa']")
    for i in title_tag:
        sr_list.append(i.text)
        
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")

    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
    time.sleep(5)
srlist= sr_list[0:100]
srlist
# Out:
# ['Precision 5 Basketball Shoes For Men',
#  'Revolution 6 Next Nature Road s Running Shoes For Men',
#  'Trendy Men Sports Running Running Shoes For Men',
#  'SOCKS Running Shoes For Men',
#  'Walking Shoes For Men',
#  'Runesy M Running Shoes For Men',
#  'MAGNITE Running Shoes For Men',
#  'Stylish Casual Sports Shoe Sneakers For Women For Women',
#  'New Design Lightweight Stylish and Tredy Sports Running...',
#  'SOCKS Training & Gym Shoes For Men',
#  'Crystal-05 Grey Running Shoes for Men I Sport Shoes for...',
#  'Running Shoes For Men',
#  'Loafers For Men',
#  'Fit-Man Slip On Sneakers For Men',
#  'Fit-Man Slip On Sneakers For Men',
#  'Spider-01 Grey Green Sports,Casual,Walking,Gym, Running...',
#  'Stylish Comfortable Lightweight, Breathable Walking Sho...',
#  'Designer Loafers For Men',
#  "Women's Mesh Sports Shoes Walking Running Shoes For Wom...",
#  'Asian Plasma-08 sports shoes for men | Latest Stylish C...',
#  'IGNITE PRO Running Shoes For Men',
# ...

# %%
item_filter = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
item_filter.click()

# %%
p_list=[]
for i in range(0,3):
    price_tag = driver.find_elements_by_xpath("//div[@class='_30jeq3']")
    for i in price_tag:
        p_list.append(i.text)
        
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")

    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
    time.sleep(5)
plist = p_list[0:100]
plist
# Out:
# ['₹3,357',
#  '₹3,645',
#  '₹249',
#  '₹398',
#  '₹1,175',
#  '₹1,870',
#  '₹749',
#  '₹359',
#  '₹319',
#  '₹379',
#  '₹1,149',
#  '₹1,149',
#  '₹218',
#  '₹159',
#  '₹159',
#  '₹549',
#  '₹269',
#  '₹222',
#  '₹539',
#  '₹2,149',
#  '₹664',
#  '₹1,750',
#  '₹1,248',
#  '₹997',
#  '₹2,990',
#  '₹249',
#  '₹598',
#  '₹997',
#  '₹448',
#  '₹249',
#  '₹367',
#  '₹289',
#  '₹348',
#  '₹449',
#  '₹297',
#  '₹373',
#  '₹222',
#  '₹334',
#  '₹649',
#  '₹1,650',
#  '₹421',
#  '₹539',
#  '₹1,749',
#  '₹449',
#  '₹997',
#  '₹225',
#  '₹206',
#  '₹2,039',
#  '₹1,599',
#  '₹410',
#  '₹599',
#  '₹3,659',
#  '₹233',
#  '₹424',
#  '₹2,023',
#  '₹1,433',
#  '₹499',
#  '₹222',
#  '₹498',
#  '₹1,139',
#  '₹438',
#  '₹249',
#  '₹1,175',
#  '₹1,379',
#  '₹648',
#  '₹199',
#  '₹2,450',
#  '₹2,253',
#  '₹2,149',
#  '₹359',
#  '₹246',
#  '₹1,677',
#  '₹399',
#  '₹399',
#  '₹249',
#  '₹2,109',
#  '₹303',
#  '₹249',
#  '₹1,039',
#  '₹324',
#  '₹437',
#  '₹398',
#  '₹159',
#  '₹2,039',
#  '₹439',
#  '₹699',
# ...

# %%
item_filter = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
item_filter.click()

# %%
d_list=[]
for i in range(0,3):
    discount_tag = driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
    for i in discount_tag:
        d_list.append(i.text)
        
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")

    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
    time.sleep(5)
dlist=d_list[0:100]
dlist
# Out:
# ['55% off',
#  '46% off',
#  '77% off',
#  '58% off',
#  '75% off',
#  '75% off',
#  '2% off',
#  '71% off',
#  '35% off',
#  '49% off',
#  '80% off',
#  '53% off',
#  '87% off',
#  '87% off',
#  '71% off',
#  '48% off',
#  '73% off',
#  '42% off',
#  '71% off',
#  '53% off',
#  '56% off',
#  '63% off',
#  '62% off',
#  '48% off',
#  '56% off',
#  '60% off',
#  '1% off',
#  '83% off',
#  '56% off',
#  '79% off',
#  '65% off',
#  '46% off',
#  '58% off',
#  '81% off',
#  '61% off',
#  '53% off',
#  '55% off',
#  '71% off',
#  '55% off',
#  '49% off',
#  '70% off',
#  '46% off',
#  '66% off',
#  '46% off',
#  '48% off',
#  '47% off',
#  '44% off',
#  '48% off',
#  '56% off',
#  '47% off',
#  '49% off',
#  '71% off',
#  '48% off',
#  '71% off',
#  '75% off',
#  '1% off',
#  '55% off',
#  '59% off',
#  '49% off',
#  '83% off',
#  '57% off',
#  '72% off',
#  '75% off',
#  '53% off',
#  '49% off',
#  '68% off',
#  '42% off',
#  '48% off',
#  '51% off',
#  '42% off',
#  '41% off',
# ...

# %%
import pandas as pd
df = pd.DataFrame({"Brand":slist, "Product Description":srlist, "Price":plist, "Discount":dlist})
df
# Out:
#        Brand                                Product Description   Price  \
# 0       NIKE               Precision 5 Basketball Shoes For Men  ₹3,357
# 1       NIKE  Revolution 6 Next Nature Road s Running Shoes ...  ₹3,645
# 2     BRUTON    Trendy Men Sports Running Running Shoes For Men    ₹249
# 3    density                        SOCKS Running Shoes For Men    ₹398
# 4   RED TAPE                              Walking Shoes For Men  ₹1,175
# ..       ...                                                ...     ...
# 95    REEBOK              Hustle V2 Wns Running Shoes For Women  ₹1,139
# 96    BRUTON                                   Sneakers For Men    ₹499
# 97     AMICO  Skypy-31 Walking Shoes,Training Shoes,Sneakers...    ₹448
# 98     ASIAN  Stylish & Trending Outdoor Walking Comfortable...    ₹549
# 99      PUMA                Edge Identity Running Shoes For Men  ₹1,379
#
#    Discount
# 0   55% off
# 1   46% off
# 2   77% off
# 3   58% off
# 4   75% off
# ..      ...
# ...

# %% [markdown]
# Q7: Go to the link - https://www.myntra.com/shoes
# Set Price filter to “Rs. 7149 to Rs. 14099 ” , Color filter to “Black”, as shown inthe below image.
# And then

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.myntra.com/shoes')

# %%
p_filter = driver.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div")
p_filter.click()

# %%
c_filter = driver.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div")
c_filter.click()

# %%
s_list=[]
for i in range(0,3):
    title_tag = driver.find_elements_by_xpath("//h3[@class='product-brand']")
    for i in title_tag:
        s_list.append(i.text)
        
    nxt_button=driver.find_elements_by_xpath("//a[@rel='next']")

    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
    
slist=s_list[0:100]
slist
# Out:
# ['Skechers',
#  'ALDO',
#  'Nike',
#  'UNDER ARMOUR',
#  'Nike',
#  'ADIDAS Originals',
#  'ALDO',
#  'ALDO',
#  'Nike',
#  'Skechers',
#  'Puma',
#  'DAVINCHI',
#  'PUMA Motorsport',
#  'ALDO',
#  'Skechers',
#  'ADIDAS Originals',
#  'Puma',
#  'Nike',
#  'UNDER ARMOUR',
#  'UNDER ARMOUR',
#  'UNDER ARMOUR',
#  'Puma',
#  'Nike',
#  'Puma',
#  'Puma',
#  'Puma',
#  'Tommy Hilfiger',
#  'Puma',
#  'Reebok',
#  'UNDER ARMOUR',
#  'UNDER ARMOUR',
#  'PUMA Motorsport',
#  'Reebok',
#  'Puma',
#  'Tommy Hilfiger',
#  'Puma',
#  'Puma',
#  'ADIDAS',
#  'Louis Philippe',
#  'Bugatti',
#  'Hush Puppies',
#  'Hush Puppies',
#  'DAVINCHI',
#  'Hush Puppies',
#  'Puma',
#  'Bugatti',
#  'DEL MONDO',
#  'Louis Philippe',
#  'ASICS',
#  'Puma',
#  'Puma',
#  'Bugatti',
#  'UNDER ARMOUR',
#  'PUMA Hoops',
#  'Hush Puppies',
#  'Bugatti',
#  'Bugatti',
#  'Puma',
#  'Bugatti',
#  'Geox',
#  'Geox',
#  'Geox',
#  'Geox',
#  'Puma',
#  'Saint G',
#  'Geox',
#  'Geox',
#  'EVADICT By Decathlon',
# ...

# %%
c_filter = driver.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div")
c_filter.click()

# %%
sr_list=[]
for i in range(0,3):
    title_tag = driver.find_elements_by_xpath("//h4[@class='product-product']")
    for i in title_tag:
        sr_list.append(i.text)
        
    nxt_button=driver.find_elements_by_xpath("//a[@rel='next']")

    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
    time.sleep(5)
srlist= sr_list[0:100]
srlist
# Out:
# ['Men Max Cushioning Running',
#  'Men Sneakers',
#  'Men React Miler2 Running Shoes',
#  'Men Charged Rouge 3 Run Shoes',
#  'Women React MR 3 Running Shoes',
#  'Men Niteball II Sneakers',
#  'Men Woven Design Sneakers',
#  'Men Leather Driving Shoes',
#  'Men AIR MAX EXCEE Sneakers',
#  'Men MAX CUSHIONING ELITE-LUCID',
#  'Electrify Nitro Running Shoes',
#  'Men Textured Formal Leather Loafers',
#  'Unisex Ferrari IONSpeed',
#  'Men Leather Loafers',
#  'Men Sky Vault Walking Shoes',
#  'Men Solid Ozweego Sneakers',
#  'Mirage Sport Hacked Sneakers',
#  'Men Air Max Dawn Sneakers',
#  'Men UA Charged Vantage 2 Run',
#  'Men Charged Breeze Running',
#  'Women Breeze Running Shoes',
#  'Men Voyage Nitro Running Shoes',
#  'Men AIR MAX PRE-DAY Sneakers',
#  'Eternity Nitro Running Shoes',
#  'Unisex Leather Trainers',
#  'Men D Nitro WTR Running Shoes',
#  'Men Leather Sneakers',
#  'Men M Nitro Running Shoess',
#  'Men Zig Dynamica 2.0 Running',
#  'Women Charged Vantage 2 Run',
# ...

# %%
p_list=[]
for i in range(0,3):
    price_tag = driver.find_elements_by_xpath("//div[@class='product-price']")
    for i in price_tag:
        p_list.append(i.text)
        
    nxt_button=driver.find_elements_by_xpath("//a[@rel='next']")

    try:

        driver.get(nxt_button[1].get_attribute('href'))

    except:

        driver.get(nxt_button[0].get_attribute('href'))
    time.sleep(5)
plist = p_list[0:100]
plist
# Out:
# ['Rs. 7199Rs. 8999(20% OFF)',
#  'Rs. 9999',
#  'Rs. 11495',
#  'Rs. 7999',
#  'Rs. 8920Rs. 10495(15% OFF)',
#  'Rs. 9349Rs. 10999(15% OFF)',
#  'Rs. 13999',
#  'Rs. 12999',
#  'Rs. 7995',
#  'Rs. 7599Rs. 9499(20% OFF)',
#  'Rs. 8499Rs. 9999(15% OFF)',
#  'Rs. 8990',
#  'Rs. 7649Rs. 8999(15% OFF)',
#  'Rs. 12999',
#  'Rs. 7199Rs. 8999(20% OFF)',
#  'Rs. 9349Rs. 10999(15% OFF)',
#  'Rs. 7199Rs. 8999(20% OFF)',
#  'Rs. 9295',
#  'Rs. 7999',
#  'Rs. 8999',
#  'Rs. 8999',
#  'Rs. 8799Rs. 10999(20% OFF)',
#  'Rs. 13995',
#  'Rs. 10399Rs. 12999(20% OFF)',
#  'Rs. 7999Rs. 9999(20% OFF)',
#  'Rs. 12799Rs. 15999(20% OFF)',
#  'Rs. 7309Rs. 8599(15% OFF)',
#  'Rs. 10399Rs. 12999(20% OFF)',
#  'Rs. 7999',
#  'Rs. 7999',
#  'Rs. 11999',
#  'Rs. 7649Rs. 8999(15% OFF)',
#  'Rs. 7999',
#  'Rs. 9599Rs. 11999(20% OFF)',
#  'Rs. 8999',
#  'Rs. 7649Rs. 8999(15% OFF)',
#  'Rs. 8799Rs. 10999(20% OFF)',
#  'Rs. 12999',
#  'Rs. 9999',
#  'Rs. 8999',
#  'Rs. 7649Rs. 8999(15% OFF)',
#  'Rs. 9999',
# ...

# %%
import pandas as pd
df = pd.DataFrame({"Brand":slist, "Product Description":srlist, "Price":plist})
df
# Out:
#            Brand             Product Description                        Price
# 0       Skechers      Men Max Cushioning Running    Rs. 7199Rs. 8999(20% OFF)
# 1           ALDO                    Men Sneakers                     Rs. 9999
# 2           Nike  Men React Miler2 Running Shoes                    Rs. 11495
# 3   UNDER ARMOUR   Men Charged Rouge 3 Run Shoes                     Rs. 7999
# 4           Nike  Women React MR 3 Running Shoes   Rs. 8920Rs. 10495(15% OFF)
# ..           ...                             ...                          ...
# 95     J.FONTINI      Men Leather Formal Loafers                     Rs. 7490
# 96          ALDO           Block Pumps with Bows                     Rs. 8999
# 97     Cole Haan           Women Leather Loafers  Rs. 11899Rs. 16999(30% OFF)
# 98          ALDO                   Wedge Sandals                     Rs. 7999
# 99          ALDO       Embellished Wedge Sandals                     Rs. 7999
#
# [100 rows x 3 columns]

# %% [markdown]
# Q8: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” and “Intel Core i9” as shown in the below image:

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.amazon.in/')

# %%
search_field_designation = search_bar = driver.find_element_by_id("twotabsearchtextbox")
search_field_designation.send_keys('Laptop')

# %%
click_result = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
click_result.click()

# %%
title_list=[]
rating_list=[]
price_list=[]

title_tag = driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']")
for i in title_tag:
    title_list.append(i.text)
title_list
# Out:
# ['Dell New Vostro 3400 Laptop, Intel i5-1135G7, Win11 + Office\'21, 8GB GDDR4, 512GB SSD, 14" (35.56Cms) FHD AG, Accent Black (D552256WIN9B, 1.59Kgs)',
#  'Lenovo IdeaPad 3 11th Gen Intel Core i5 15.6" FHD Thin & Light Laptop (8 GB/512GB SDD/Windows 11/Office 2021/Backlit Keyboard/2Yr Warranty/Arctic Grey/1.65Kg), 82H801L6IN',
#  'ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) HD, Dual Core Intel Celeron N4020, Thin and Light Laptop (4GB RAM/256GB SSD/Integrated Graphics/Windows 11 Home/Transparent Silver/1.8 Kg), X515MA-BR011W',
#  "Lenovo IdeaPad 3 Intel Celeron N4020 14'' HD Thin & Light Laptop (4GB/256GB SSD/Windows 11/MS Office 2021/Platinum Grey/1.5Kg), 81WH007KIN",
#  "Lenovo IdeaPad 1 Intel Celeron N4020 11.6'' HD Laptop (4GB/256GB SSD/Windows 11/Office 2021/Platinum Grey/1.2Kg), 81VT009UIN",
#  'Lenovo ThinkPad E14 Intel Core i3 10th Gen 14 inches Full HD Business Laptop (4GB RAM/ 256GB SSD/ DOS/ Black/ 1.69 kg), 20RAS0SE00',
# ...

# %%
for i in range(0,10):
    rating_tag = driver.find_elements_by_xpath("//a[@class='a-link-normal s-underline-text s-underline-link-text s-link-style']")
    driver.get(rating_tag[1].get_attribute('href'))
    rate_tag = driver.find_elements_by_xpath("//div[@class='a-fixed-left-grid-col aok-align-center a-col-right']")
    for i in rate_tag:
        rating_list.append(i.text)
    rating_list
click_result = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
click_result.click()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3468/3027637522.py in <module>
#       1 for i in range(0,10):
#       2     rating_tag = driver.find_elements_by_xpath("//a[@class='a-link-normal s-underline-text s-underline-link-text s-link-style']")
# ----> 3     driver.get(rating_tag[1].get_attribute('href'))
#       4     rate_tag = driver.find_elements_by_xpath("//div[@class='a-fixed-left-grid-col aok-align-center a-col-right']")
#       5     for i in rate_tag:
#
# IndexError: list index out of range

# %% [markdown]
# Q9: Write a python program to scrape data for first 10 job results for Data Scientist Designation in Noida location. You have to scrape company name, No. of days ago when job was posted, Rating of the company. This task will be done in following steps:

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.ambitionbox.com/')

# %%
search_field_designation = driver.find_element_by_xpath("/html/body/section[1]/div/div[2]/form/span/input") #job search.bar
search_field_designation.send_keys('Data Scientist Noida')

# %%
search_button = driver.find_element_by_xpath('/html/body/section[1]/div/div[2]/form/div[2]/input')
search_button.click()

# %%
c_name= []

c_title = driver.find_elements_by_xpath("//a[@class='gs-title']")
for i in c_title:
    c_name.append(i.text)
    
c_name
# Out:
# ['R Systems International Data Scientist Salaries in Noida | AmbitionBox',
#  '',
#  'Data Scientist Salary in Noida | AmbitionBox',
#  '',
#  'GlobalLogic Data Scientist Salaries in Noida | AmbitionBox',
#  '',
#  'IBM Data Scientist Salaries in Noida | AmbitionBox',
#  '',
#  'Sopra Steria Data Scientist Salaries in Noida | AmbitionBox',
#  '',
#  'Biz 2 Credit Info Services Data Scientist Salaries in Noida ...',
#  '',
#  'TCS Data Scientist Salaries in Noida | AmbitionBox',
#  '',
#  'Senior Data Scientist Salary in Noida | AmbitionBox',
#  '',
#  'Pitney Bowes Data Scientist Salaries in Noida | AmbitionBox',
#  '',
#  'Ericsson Data Scientist Salaries in Noida | AmbitionBox',
#  '',
#  '',
#  '',
#  '']

# %%
for i in range(0,1):
    nxt_button=driver.find_elements_by_xpath("//a[@class='gs-title']")
    driver.get(nxt_button[1].get_attribute('href'))
    C_name = driver.find_element_by_xpath("//p[@class='h1 headerTextWrapper mg-btm-4']")
    C_name
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3468/3671380799.py in <module>
#       1 for i in range(0,1):
#       2     nxt_button=driver.find_elements_by_xpath("//a[@class='gs-title']")
# ----> 3     driver.get(nxt_button[1].get_attribute('href'))
#       4     C_name = driver.find_element_by_xpath("//p[@class='h1 headerTextWrapper mg-btm-4']")
#       5     C_name
#
# IndexError: list index out of range
