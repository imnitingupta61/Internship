# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
driver= webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://easemytrip.com/')

# %%
flight= driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div[2]/div[2]/div[1]/ul/li[1]/a')
flight.click()

# %%
search= driver.find_element_by_xpath('/html/body/div[6]/div/div[3]/div[1]/div[7]/input')
search.click()

# %%
fly_name=[]
D_O_J=[]
source=[]
destignation=[]
ti_take=[]
arrival_time=[]
reached_time=[]
total_stops=[]
fly_fare=[]
fly_price=[]

# %%
fl= driver.find_elements_by_xpath('//span[@class="txt-r4 ng-binding"]')
for i in fl:
    fly_name.append(i.text)
    
so= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[2]')
for i in so:
    source.append(i.text)
    
de= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[2]')
for i in de:
    destignation.append(i.text)
    
at= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[1]')
for i in at:
    arrival_time.append(i.text)
    
rt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[1]')
for i in rt:
    reached_time.append(i.text)

tt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[1]')
for i in tt:
    ti_take.append(i.text)
    
ts= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[2]')
for i in ts:
    total_stops.append(i.text)

fp= driver.find_elements_by_xpath('//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
for i in fp:
    fly_price.append(i.text)

# %%
for i in range(0,len(fly_name)):
    jo= driver.find_elements_by_xpath('//div[@class="ai-d ng-binding fnt17"]')
    for j in jo:
        D_O_J.append(j.text)

# %%
date= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[5]/div/div[2]/div[1]/div/div[1]/div[2]/div/div/div/div/div/div[2]/div[3]/div[1]/div[1]/div[2]/span')
date.click()

# %%
fl= driver.find_elements_by_xpath('//span[@class="txt-r4 ng-binding"]')
for i in fl:
    fly_name.append(i.text)
    
so= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[2]')
for i in so:
    source.append(i.text)
    
de= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[2]')
for i in de:
    destignation.append(i.text)
    
at= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[1]')
for i in at:
    arrival_time.append(i.text)
    
rt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[1]')
for i in rt:
    reached_time.append(i.text)

tt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[1]')
for i in tt:
    ti_take.append(i.text)
    
ts= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[2]')
for i in ts:
    total_stops.append(i.text)

fp= driver.find_elements_by_xpath('//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
for i in fp:
    fly_price.append(i.text)

# %%
for i in range(len(D_O_J),len(fly_name)):
    jo= driver.find_elements_by_xpath('//div[@class="ai-d ng-binding fnt17"]')
    for j in jo:
        D_O_J.append(j.text)

# %%
date= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[5]/div/div[2]/div[1]/div/div[1]/div[2]/div/div/div/div/div/div[2]/div[4]/div[1]/div[1]/div[1]')
date.click()

# %%
fl= driver.find_elements_by_xpath('//span[@class="txt-r4 ng-binding"]')
for i in fl:
    fly_name.append(i.text)
    
so= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[2]')
for i in so:
    source.append(i.text)
    
de= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[2]')
for i in de:
    destignation.append(i.text)
    
at= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[1]')
for i in at:
    arrival_time.append(i.text)
    
rt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[1]')
for i in rt:
    reached_time.append(i.text)

tt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[1]')
for i in tt:
    ti_take.append(i.text)
    
ts= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[2]')
for i in ts:
    total_stops.append(i.text)

fp= driver.find_elements_by_xpath('//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
for i in fp:
    fly_price.append(i.text)

# %%
for i in range(len(D_O_J),len(fly_name)):
    jo= driver.find_elements_by_xpath('//div[@class="ai-d ng-binding fnt17"]')
    for j in jo:
        D_O_J.append(j.text)

# %%
put= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[1]/div[3]/input[2]')
put.click()

# %%
select= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[1]/div[3]/div/div/div/ul/li[2]/div[1]/span[2]')
select.click()

# %%
swap= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[1]/div[4]/a/i')
swap.click()

# %%
search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[3]/button[1]')
search.click()

# %%
date= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[5]/div/div[2]/div[1]/div/div[1]/div[2]/div/div/div/div/div/div[2]/div[2]/div[1]/div[1]/div[1]')
date.click()

# %%
fl= driver.find_elements_by_xpath('//span[@class="txt-r4 ng-binding"]')
for i in fl:
    fly_name.append(i.text)
    
so= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[2]')
for i in so:
    source.append(i.text)
    
de= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[2]')
for i in de:
    destignation.append(i.text)
    
at= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[1]')
for i in at:
    arrival_time.append(i.text)
    
rt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[1]')
for i in rt:
    reached_time.append(i.text)

tt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[1]')
for i in tt:
    ti_take.append(i.text)
    
ts= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[2]')
for i in ts:
    total_stops.append(i.text)

fp= driver.find_elements_by_xpath('//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
for i in fp:
    fly_price.append(i.text)

# %%
for i in range(len(D_O_J),len(fly_name)):
    jo= driver.find_elements_by_xpath('//div[@class="ai-d ng-binding fnt17"]')
    for j in jo:
        D_O_J.append(j.text)

# %%
date= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[5]/div/div[2]/div[1]/div/div[1]/div[2]/div/div/div/div/div/div[2]/div[3]/div[1]/div[1]/div[1]')
date.click()

# %%
fl= driver.find_elements_by_xpath('//span[@class="txt-r4 ng-binding"]')
for i in fl:
    fly_name.append(i.text)
    
so= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[2]')
for i in so:
    source.append(i.text)
    
de= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[2]')
for i in de:
    destignation.append(i.text)
    
at= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[1]')
for i in at:
    arrival_time.append(i.text)
    
rt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[1]')
for i in rt:
    reached_time.append(i.text)

tt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[1]')
for i in tt:
    ti_take.append(i.text)
    
ts= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[2]')
for i in ts:
    total_stops.append(i.text)

fp= driver.find_elements_by_xpath('//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
for i in fp:
    fly_price.append(i.text)

# %%
for i in range(len(D_O_J),len(fly_name)):
    jo= driver.find_elements_by_xpath('//div[@class="ai-d ng-binding fnt17"]')
    for j in jo:
        D_O_J.append(j.text)

# %%
date= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[5]/div/div[2]/div[1]/div/div[1]/div[2]/div/div/div/div/div/div[2]/div[4]/div[1]/div[1]/div[1]')
date.click()

# %%
fl= driver.find_elements_by_xpath('//span[@class="txt-r4 ng-binding"]')
for i in fl:
    fly_name.append(i.text)
    
so= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[2]')
for i in so:
    source.append(i.text)
    
de= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[2]')
for i in de:
    destignation.append(i.text)
    
at= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[1]')
for i in at:
    arrival_time.append(i.text)
    
rt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[1]')
for i in rt:
    reached_time.append(i.text)

tt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[1]')
for i in tt:
    ti_take.append(i.text)
    
ts= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[2]')
for i in ts:
    total_stops.append(i.text)

fp= driver.find_elements_by_xpath('//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
for i in fp:
    fly_price.append(i.text)

# %%
for i in range(len(D_O_J),len(fly_name)):
    jo= driver.find_elements_by_xpath('//div[@class="ai-d ng-binding fnt17"]')
    for j in jo:
        D_O_J.append(j.text)

# %%
put= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[1]/div[3]/input[2]')
put.click()

# %%
select= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[1]/div[3]/div/div/div/ul/li[7]/div[1]/span[2]')
select.click()

# %%
put= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[1]/div[5]/input[2]')
put.click()

# %%
select2= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[1]/div[5]/div/div/div/ul/li[1]/div[2]/span[1]')
select2.click()

# %%
search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[3]/button[1]')
search.click()

# %%
date= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[5]/div/div[2]/div[1]/div/div[1]/div[2]/div/div/div/div/div/div[2]/div[2]/div[1]/div[1]/div[1]')
date.click()

# %%
fl= driver.find_elements_by_xpath('//span[@class="txt-r4 ng-binding"]')
for i in fl:
    fly_name.append(i.text)
    
so= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[2]')
for i in so:
    source.append(i.text)
    
de= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[2]')
for i in de:
    destignation.append(i.text)
    
at= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[1]')
for i in at:
    arrival_time.append(i.text)
    
rt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[1]')
for i in rt:
    reached_time.append(i.text)

tt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[1]')
for i in tt:
    ti_take.append(i.text)
    
ts= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[2]')
for i in ts:
    total_stops.append(i.text)

fp= driver.find_elements_by_xpath('//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
for i in fp:
    fly_price.append(i.text)

# %%
for i in range(len(D_O_J),len(fly_name)):
    jo= driver.find_elements_by_xpath('//div[@class="ai-d ng-binding fnt17"]')
    for j in jo:
        D_O_J.append(j.text)

# %%
print(len(fly_name),len(source),len(destignation),len(reached_time),len(arrival_time),len(total_stops),len(D_O_J))
# Out:
# 826 826 826 826 826 826 826

# %%
date= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[5]/div/div[2]/div[1]/div/div[1]/div[2]/div/div/div/div/div/div[2]/div[3]/div[1]/div[1]/div[1]')
date.click()

# %%
fl= driver.find_elements_by_xpath('//span[@class="txt-r4 ng-binding"]')
for i in fl:
    fly_name.append(i.text)
    
so= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[2]')
for i in so:
    source.append(i.text)
    
de= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[2]')
for i in de:
    destignation.append(i.text)
    
at= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[1]')
for i in at:
    arrival_time.append(i.text)
    
rt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[1]')
for i in rt:
    reached_time.append(i.text)

tt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[1]')
for i in tt:
    ti_take.append(i.text)
    
ts= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[2]')
for i in ts:
    total_stops.append(i.text)

fp= driver.find_elements_by_xpath('//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
for i in fp:
    fly_price.append(i.text)

# %%
for i in range(len(D_O_J),len(fly_name)):
    jo= driver.find_elements_by_xpath('//div[@class="ai-d ng-binding fnt17"]')
    for j in jo:
        D_O_J.append(j.text)

# %%
date= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[5]/div/div[2]/div[1]/div/div[1]/div[2]/div/div/div/div/div/div[2]/div[4]/div[1]/div[1]/div[2]/span')
date.click()

# %%
fl= driver.find_elements_by_xpath('//span[@class="txt-r4 ng-binding"]')
for i in fl:
    fly_name.append(i.text)
    
so= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[2]')
for i in so:
    source.append(i.text)
    
de= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[2]')
for i in de:
    destignation.append(i.text)
    
at= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[1]')
for i in at:
    arrival_time.append(i.text)
    
rt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[1]')
for i in rt:
    reached_time.append(i.text)

tt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[1]')
for i in tt:
    ti_take.append(i.text)
    
ts= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[2]')
for i in ts:
    total_stops.append(i.text)

fp= driver.find_elements_by_xpath('//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
for i in fp:
    fly_price.append(i.text)

# %%
for i in range(len(D_O_J),len(fly_name)):
    jo= driver.find_elements_by_xpath('//div[@class="ai-d ng-binding fnt17"]')
    for j in jo:
        D_O_J.append(j.text)

# %%
put= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[1]/div[3]/input[2]')
put.click()

# %%
select= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[1]/div[3]/div/div/div/ul/li[4]/div[1]/span[2]')
select.click()

# %%
put= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[1]/div[5]/input[2]')
put.click()

# %%
select2= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[1]/div[5]/div/div/div/ul/li[3]/div[1]/span[2]')
select2.click()

# %%
search= driver.find_element_by_xpath('/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[3]/button[1]')
search.click()

# %%
date= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[5]/div/div[2]/div[1]/div/div[1]/div[2]/div/div/div/div/div/div[2]/div[2]/div[1]/div[1]/div[1]')
date.click()

# %%
fl= driver.find_elements_by_xpath('//span[@class="txt-r4 ng-binding"]')
for i in fl:
    fly_name.append(i.text)
    
so= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[2]')
for i in so:
    source.append(i.text)
    
de= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[2]')
for i in de:
    destignation.append(i.text)
    
at= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[1]')
for i in at:
    arrival_time.append(i.text)
    
rt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[1]')
for i in rt:
    reached_time.append(i.text)

tt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[1]')
for i in tt:
    ti_take.append(i.text)
    
ts= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[2]')
for i in ts:
    total_stops.append(i.text)

fp= driver.find_elements_by_xpath('//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
for i in fp:
    fly_price.append(i.text)

# %%
for i in range(len(D_O_J),len(fly_name)):
    jo= driver.find_elements_by_xpath('//div[@class="ai-d ng-binding fnt17"]')
    for j in jo:
        D_O_J.append(j.text)

# %%
date= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[5]/div/div[2]/div[1]/div/div[1]/div[2]/div/div/div/div/div/div[2]/div[3]/div[1]/div[1]/div[1]')
date.click()

# %%
fl= driver.find_elements_by_xpath('//span[@class="txt-r4 ng-binding"]')
for i in fl:
    fly_name.append(i.text)
    
so= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[2]')
for i in so:
    source.append(i.text)
    
de= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[2]')
for i in de:
    destignation.append(i.text)
    
at= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[1]')
for i in at:
    arrival_time.append(i.text)
    
rt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[1]')
for i in rt:
    reached_time.append(i.text)

tt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[1]')
for i in tt:
    ti_take.append(i.text)
    
ts= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[2]')
for i in ts:
    total_stops.append(i.text)

fp= driver.find_elements_by_xpath('//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
for i in fp:
    fly_price.append(i.text)

# %%
for i in range(len(D_O_J),len(fly_name)):
    jo= driver.find_elements_by_xpath('//div[@class="ai-d ng-binding fnt17"]')
    for j in jo:
        D_O_J.append(j.text)

# %%
date= search= driver.find_element_by_xpath('/html/body/form/div[9]/div[5]/div/div[2]/div[1]/div/div[1]/div[2]/div/div/div/div/div/div[2]/div[4]/div[1]/div[1]/div[2]/span')
date.click()

# %%
fl= driver.find_elements_by_xpath('//span[@class="txt-r4 ng-binding"]')
for i in fl:
    fly_name.append(i.text)
    
so= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[2]')
for i in so:
    source.append(i.text)
    
de= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[2]')
for i in de:
    destignation.append(i.text)
    
at= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-4 top5 "]/span[1]')
for i in at:
    arrival_time.append(i.text)
    
rt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-3 top5"]/span[1]')
for i in rt:
    reached_time.append(i.text)

tt= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[1]')
for i in tt:
    ti_take.append(i.text)
    
ts= driver.find_elements_by_xpath('//div[@class="col-md-2 col-sm-2 col-xs-5 non-st"]/span[2]')
for i in ts:
    total_stops.append(i.text)

fp= driver.find_elements_by_xpath('//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
for i in fp:
    fly_price.append(i.text)

# %%
for i in range(len(D_O_J),len(fly_name)):
    jo= driver.find_elements_by_xpath('//div[@class="ai-d ng-binding fnt17"]')
    for j in jo:
        D_O_J.append(j.text)

# %%
df= pd.DataFrame({'Flight_Name':fly_name, 'Source':source, "Destignation":destignation, "Arrival_Time": arrival_time, 'Reached_Time':reached_time, "Total_Time": ti_take, 'Total_stops':total_stops, 'Date_of_Journey':D_O_J, "Flight_Price":fly_price})

# %%
df
# Out:
#      Flight_Name   Source Destignation Arrival_Time Reached_Time Total_Time  \
# 0      Air India    Delhi       Mumbai        20:00        22:10    02h 10m
# 1      Air India    Delhi       Mumbai        21:15        23:35    02h 20m
# 2       SpiceJet    Delhi       Mumbai        20:00        22:15    02h 15m
# 3       SpiceJet    Delhi       Mumbai        21:40        23:55    02h 15m
# 4       GO FIRST    Delhi       Mumbai        19:50        22:00    02h 10m
# ...          ...      ...          ...          ...          ...        ...
# 1379     Vistara  Kolkata       Mumbai        10:15        19:00    08h 45m
# 1380   Air India  Kolkata       Mumbai        20:15        16:25    20h 10m
# 1381   Air India  Kolkata       Mumbai        15:30        16:25    24h 55m
# 1382   Air India  Kolkata       Mumbai        10:30        16:25    29h 55m
# 1383   Air India  Kolkata       Mumbai        06:50        18:05    11h 15m
#
#      Total_stops Date_of_Journey Flight_Price
# ...

# %% [markdown]
# # Machine Learning Model

# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
df
# Out:
#      Flight_Name   Source Destignation Arrival_Time Reached_Time Total_Time  \
# 0      Air India    Delhi       Mumbai        20:00        22:10    02h 10m
# 1      Air India    Delhi       Mumbai        21:15        23:35    02h 20m
# 2       SpiceJet    Delhi       Mumbai        20:00        22:15    02h 15m
# 3       SpiceJet    Delhi       Mumbai        21:40        23:55    02h 15m
# 4       GO FIRST    Delhi       Mumbai        19:50        22:00    02h 10m
# ...          ...      ...          ...          ...          ...        ...
# 1379     Vistara  Kolkata       Mumbai        10:15        19:00    08h 45m
# 1380   Air India  Kolkata       Mumbai        20:15        16:25    20h 10m
# 1381   Air India  Kolkata       Mumbai        15:30        16:25    24h 55m
# 1382   Air India  Kolkata       Mumbai        10:30        16:25    29h 55m
# 1383   Air India  Kolkata       Mumbai        06:50        18:05    11h 15m
#
#      Total_stops Date_of_Journey Flight_Price
# ...

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# Flight_Name        0
# Source             0
# Destignation       0
# Arrival_Time       0
# Reached_Time       0
# Total_Time         0
# Total_stops        0
# Date_of_Journey    0
# Flight_Price       0
# dtype: int64

# %% [markdown]
# it is showing flight price 0 null values but there are so many nul values present.

# %%
df.columns
# Out:
# Index(['Flight_Name', 'Source', 'Destignation', 'Arrival_Time', 'Reached_Time',
#        'Total_Time', 'Total_stops', 'Date_of_Journey', 'Flight_Price'],
#       dtype='object')

# %%
df['Flight_Price'].unique()
# Out:
# array(['6,480', '', '8,578', '8,714', '8,579', '8,580', '9,105', '10,155',
#        '10,861', '11,762', '11,435', '11,835', '12,990', '13,220',
#        '14,668', '14,105', '14,291', '15,600', '15,665', '16,665',
#        '16,140', '17,327', '17,988', '18,377', '18,658', '18,660',
#        '19,038', '19,185', '19,603', '19,710', '19,742', '19,920',
#        '20,235', '20,403', '20,655', '20,760', '21,075', '22,246',
#        '22,545', '25,328', '26,115', '28,528', '5,955', '6,092', '9,086',
#        '9,000', '9,293', '9,840', '10,073', '10,451', '10,007', '10,993',
#        '10,721', '11,518', '10,996', '12,336', '12,463', '12,988',
#        '12,110', '12,307', '12,506', '12,727', '13,844', '12,863',
#        '13,305', '14,141', '14,143', '14,479', '14,852', '14,670',
#        '14,804', '14,838', '14,040', '14,071', '14,983', '15,468',
#        '15,505', '15,332', '15,395', '15,694', '15,510', '16,002',
#        '15,962', '16,138', '16,274', '15,575', '15,582', '17,606',
# ...

# %%
df.loc[df['Flight_Price']=='']
# Out:
#      Flight_Name   Source Destignation Arrival_Time Reached_Time Total_Time  \
# 2       SpiceJet    Delhi       Mumbai        20:00        22:15    02h 15m
# 3       SpiceJet    Delhi       Mumbai        21:40        23:55    02h 15m
# 4       GO FIRST    Delhi       Mumbai        19:50        22:00    02h 10m
# 5       GO FIRST    Delhi       Mumbai        17:30        19:45    02h 15m
# 6       GO FIRST    Delhi       Mumbai        20:50        23:05    02h 15m
# ...          ...      ...          ...          ...          ...        ...
# 1340    GO FIRST  Kolkata       Mumbai        05:45        16:40    10h 55m
# 1341    GO FIRST  Kolkata       Mumbai        05:45        22:00    16h 15m
# 1343     AirAsia  Kolkata       Mumbai        18:40        07:15    12h 35m
# 1345    GO FIRST  Kolkata       Mumbai        14:20        22:00    07h 40m
# 1346    GO FIRST  Kolkata       Mumbai        14:20        01:00    10h 40m
#
#      Total_stops Date_of_Journey Flight_Price
# ...

# %%
df['Flight_Price']=df['Flight_Price'].replace('',np.nan)

# %%
df.isnull().sum()
# Out:
# Flight_Name          0
# Source               0
# Destignation         0
# Arrival_Time         0
# Reached_Time         0
# Total_Time           0
# Total_stops          0
# Date_of_Journey      0
# Flight_Price       185
# dtype: int64

# %% [markdown]
# Converting column type from object to float

# %%
df['Flight_Price'] = df['Flight_Price'].str.replace(',','')

# %%
df['Flight_Price']= df['Flight_Price'].astype(float)

# %%
df.dtypes
# Out:
# Flight_Name         object
# Source              object
# Destignation        object
# Arrival_Time        object
# Reached_Time        object
# Total_Time          object
# Total_stops         object
# Date_of_Journey     object
# Flight_Price       float64
# dtype: object

# %% [markdown]
# Dropping null values as 185 null values found filling null values is no use

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      Flight_Name   Source Destignation Arrival_Time Reached_Time Total_Time  \
# 0      Air India    Delhi       Mumbai        20:00        22:10    02h 10m
# 1      Air India    Delhi       Mumbai        21:15        23:35    02h 20m
# 14       Vistara    Delhi       Mumbai        19:45        21:55    02h 10m
# 15       Vistara    Delhi       Mumbai        19:00        21:15    02h 15m
# 16       Vistara    Delhi       Mumbai        18:10        09:40    15h 30m
# ...          ...      ...          ...          ...          ...        ...
# 1379     Vistara  Kolkata       Mumbai        10:15        19:00    08h 45m
# 1380   Air India  Kolkata       Mumbai        20:15        16:25    20h 10m
# 1381   Air India  Kolkata       Mumbai        15:30        16:25    24h 55m
# 1382   Air India  Kolkata       Mumbai        10:30        16:25    29h 55m
# 1383   Air India  Kolkata       Mumbai        06:50        18:05    11h 15m
#
#      Total_stops Date_of_Journey  Flight_Price
# ...

# %% [markdown]
# As per above data set all values are catagorical type whose data type is object. Only Price has data type float which is Numerical data type also a target variable

# %%
df.Total_stops.unique()
# Out:
# array(['non-stop', '1-stop', '1-stop Via IXU', '2+-stop',
#        '1-stop Via Indore', '1-stop Via CNN', '1-stop Via IDR',
#        '1-stop Via Delhi'], dtype=object)

# %% [markdown]
# Converitng Date of journey in date and year columns but date is not in day month year so no need of

# %%
Now split "Arrival_Time" column into Hour & Min

# %%
df['Arrival_Time'].dtypes

df['Arrival_Time'] = pd.to_datetime(df['Arrival_Time'])

# %%
#For Hour

df['Arrival_hour'] = df['Arrival_Time'].dt.hour

df['Arrival_hour'].head()
# Out:
# 0     20
# 1     21
# 14    19
# 15    19
# 16    18
# Name: Arrival_hour, dtype: int64

# %%
#For Min

df['Arrival_minute'] = df['Arrival_Time'].dt.minute

df['Arrival_minute'].head()
# Out:
# 0      0
# 1     15
# 14    45
# 15     0
# 16    10
# Name: Arrival_minute, dtype: int64

# %%
df.head()
# Out:
#    Flight_Name Source Destignation        Arrival_Time Reached_Time  \
# 0    Air India  Delhi       Mumbai 2022-08-12 20:00:00        22:10
# 1    Air India  Delhi       Mumbai 2022-08-12 21:15:00        23:35
# 14     Vistara  Delhi       Mumbai 2022-08-12 19:45:00        21:55
# 15     Vistara  Delhi       Mumbai 2022-08-12 19:00:00        21:15
# 16     Vistara  Delhi       Mumbai 2022-08-12 18:10:00        09:40
#
#    Total_Time Total_stops Date_of_Journey  Flight_Price  Arrival_hour  \
# 0     02h 10m    non-stop          Aug 12        6480.0            20
# 1     02h 20m    non-stop          Aug 12        6480.0            21
# 14    02h 10m    non-stop          Aug 12        8578.0            19
# 15    02h 15m    non-stop          Aug 12        8578.0            19
# 16    15h 30m      1-stop          Aug 12        8714.0            18
#
#     Arrival_minute
# 0                0
# 1               15
# 14              45
# 15               0
# 16              10

# %% [markdown]
# Dropping column Arrival_Time

# %%
df.drop('Arrival_Time',inplace=True,axis=1)

# %% [markdown]
# Now split "Reached_Time" column into Hour & Min

# %%
df['Reached_Time'].dtypes

df['Reached_Time'] = pd.to_datetime(df['Reached_Time'])

# %%
#For Hour

df['Reached_hour'] = df['Reached_Time'].dt.hour

df['Reached_hour'].head()
# Out:
# 0     22
# 1     23
# 14    21
# 15    21
# 16     9
# Name: Reached_hour, dtype: int64

# %%
#For  minutes

df['Reached_minutes'] = df['Reached_Time'].dt.minute

df['Reached_minutes'].head()
# Out:
# 0     10
# 1     35
# 14    55
# 15    15
# 16    40
# Name: Reached_minutes, dtype: int64

# %%
df.head()
# Out:
#    Flight_Name Source Destignation        Reached_Time Total_Time Total_stops  \
# 0    Air India  Delhi       Mumbai 2022-08-12 22:10:00    02h 10m    non-stop
# 1    Air India  Delhi       Mumbai 2022-08-12 23:35:00    02h 20m    non-stop
# 14     Vistara  Delhi       Mumbai 2022-08-12 21:55:00    02h 10m    non-stop
# 15     Vistara  Delhi       Mumbai 2022-08-12 21:15:00    02h 15m    non-stop
# 16     Vistara  Delhi       Mumbai 2022-08-12 09:40:00    15h 30m      1-stop
#
#    Date_of_Journey  Flight_Price  Arrival_hour  Arrival_minute  Reached_hour  \
# 0           Aug 12        6480.0            20               0            22
# 1           Aug 12        6480.0            21              15            23
# 14          Aug 12        8578.0            19              45            21
# 15          Aug 12        8578.0            19               0            21
# 16          Aug 12        8714.0            18              10             9
#
#     Reached_minutes
# ...

# %% [markdown]
# Dropping Reached Time

# %%
df.drop('Reached_Time',inplace=True,axis=1)

# %%
df.head()
# Out:
#    Flight_Name Source Destignation Total_Time Total_stops Date_of_Journey  \
# 0    Air India  Delhi       Mumbai    02h 10m    non-stop          Aug 12
# 1    Air India  Delhi       Mumbai    02h 20m    non-stop          Aug 12
# 14     Vistara  Delhi       Mumbai    02h 10m    non-stop          Aug 12
# 15     Vistara  Delhi       Mumbai    02h 15m    non-stop          Aug 12
# 16     Vistara  Delhi       Mumbai    15h 30m      1-stop          Aug 12
#
#     Flight_Price  Arrival_hour  Arrival_minute  Reached_hour  Reached_minutes
# 0         6480.0            20               0            22               10
# 1         6480.0            21              15            23               35
# 14        8578.0            19              45            21               55
# 15        8578.0            19               0            21               15
# 16        8714.0            18              10             9               40

# %% [markdown]
# Total Time also taking hours and minutes combined lest split hours and minutes

# %%
def get_total_time(x):
    x=x.split(' ')
    hours=0
    mins=0
    if len(x)==1:
        x=x[0]
        if x[-1]=='h':
            hours=int(x[:-1])
        else:
            mins=int(x[:-1])
    else:
        hours=int(x[0][:-1])
        mins=int(x[1][:-1])
    return hours,mins
df['Total_hours']=df.Total_Time.apply(lambda x:get_total_time(x)[0])
df['Total_mins']=df.Total_Time.apply(lambda x:get_total_time(x)[1])
df.drop(["Total_Time"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Flight_Name Source Destignation Total_stops Date_of_Journey  Flight_Price  \
# 0    Air India  Delhi       Mumbai    non-stop          Aug 12        6480.0
# 1    Air India  Delhi       Mumbai    non-stop          Aug 12        6480.0
# 14     Vistara  Delhi       Mumbai    non-stop          Aug 12        8578.0
# 15     Vistara  Delhi       Mumbai    non-stop          Aug 12        8578.0
# 16     Vistara  Delhi       Mumbai      1-stop          Aug 12        8714.0
#
#     Arrival_hour  Arrival_minute  Reached_hour  Reached_minutes  Total_hours  \
# 0             20               0            22               10            2
# 1             21              15            23               35            2
# 14            19              45            21               55            2
# 15            19               0            21               15            2
# 16            18              10             9               40           15
#
#     Total_mins
# 0           10
# ...

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="Flight_Name", y="Flight_Price", data = df)
# Out:
# <AxesSubplot:xlabel='Flight_Name', ylabel='Flight_Price'>

# %% [markdown]
# As per above visualization AirAsia has lowest price as per aother airlines and Vistara has highest price

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="Date_of_Journey", y="Flight_Price", data = df)
# Out:
# <AxesSubplot:xlabel='Date_of_Journey', ylabel='Flight_Price'>

# %% [markdown]
# As per above visualization highest price is taken on 12th August and most outliers present on 13th Aug

# %%
sns.displot(df["Date_of_Journey"],kde=True)

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="Source", y="Flight_Price", data = df)
# Out:
# <AxesSubplot:xlabel='Source', ylabel='Flight_Price'>

# %% [markdown]
# As per above visualization we can see the max price paid for chennai location and less is for mumbai but all 3 are almost similar

# %%
sns.displot(df["Source"],kde=True)

# %%
sns.displot(df["Flight_Price"],kde=True)

# %% [markdown]
# as per above visualization price is little right skewed

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['Flight_Name'], palette='Set3')
plt.title('Count of Flights', size=30)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# As per above max number of flights are Vistara

# %%
df.corr()
# Out:
#                  Flight_Price  Arrival_hour  Arrival_minute  Reached_hour  \
# Flight_Price         1.000000      0.045041        0.012212      0.062653
# Arrival_hour         0.045041      1.000000        0.156642     -0.052750
# Arrival_minute       0.012212      0.156642        1.000000      0.033719
# Reached_hour         0.062653     -0.052750        0.033719      1.000000
# Reached_minutes     -0.067460     -0.036405        0.048857     -0.011072
# Total_hours          0.383198      0.156039        0.114657     -0.051053
# Total_mins           0.003505      0.017573        0.109276      0.052397
#
#                  Reached_minutes  Total_hours  Total_mins
# Flight_Price           -0.067460     0.383198    0.003505
# Arrival_hour           -0.036405     0.156039    0.017573
# Arrival_minute          0.048857     0.114657    0.109276
# Reached_hour           -0.011072    -0.051053    0.052397
# Reached_minutes         1.000000    -0.032834    0.062340
# ...

# %%
plt.title('Correlation Matrix\n')
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'Flight_Price'}>,
#         <AxesSubplot:title={'center':'Arrival_hour'}>,
#         <AxesSubplot:title={'center':'Arrival_minute'}>],
#        [<AxesSubplot:title={'center':'Reached_hour'}>,
#         <AxesSubplot:title={'center':'Reached_minutes'}>,
#         <AxesSubplot:title={'center':'Total_hours'}>],
#        [<AxesSubplot:title={'center':'Total_mins'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # Label Encodder

# %%
df_new = pd.get_dummies(df, columns=['Flight_Name','Source','Destignation','Date_of_Journey'], drop_first=True)

# %%
df_new.head()
# Out:
#    Total_stops  Flight_Price  Arrival_hour  Arrival_minute  Reached_hour  \
# 0     non-stop        6480.0            20               0            22
# 1     non-stop        6480.0            21              15            23
# 14    non-stop        8578.0            19              45            21
# 15    non-stop        8578.0            19               0            21
# 16      1-stop        8714.0            18              10             9
#
#     Reached_minutes  Total_hours  Total_mins  Flight_Name_AirAsia  \
# 0                10            2          10                    0
# 1                35            2          20                    0
# 14               55            2          10                    0
# 15               15            2          15                    0
# 16               40           15          30                    0
#
#     Flight_Name_GO FIRST  Flight_Name_Indigo  Flight_Name_SpiceJet  \
# ...

# %%
df_new['Total_stops'] = df_new['Total_stops'].map({"non-stop": 0, "1-stop": 1, "1-stop Via IXU": 2, "2+-stop": 3, "1-stop Via Indore": 4,"1-stop Via CNN": 5,"1-stop Via IDR": 6,"1-stop Via Delhi": 7})

# %%
df_new.shape
# Out:
# (1199, 20)

# %% [markdown]
# # Splitting Data Set

# %%
X = df_new.drop('Flight_Price', axis=1)      
y = df_new['Flight_Price']

# %% [markdown]
# # Scaling using Min_Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

mn=MinMaxScaler()
X=mn.fit_transform(X)

# %% [markdown]
# # Importing Model

# %%
import sklearn
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
ne = KNeighborsRegressor(n_neighbors=2)
dt = DecisionTreeRegressor()
rf= RandomForestRegressor()
ab= AdaBoostRegressor()
rd= Ridge()
mod = [ne, dt, rf, ab, rd]
mod
# Out:
# [KNeighborsRegressor(n_neighbors=2),
#  DecisionTreeRegressor(),
#  RandomForestRegressor(),
#  AdaBoostRegressor(),
#  Ridge()]

# %%
for j in mod:
    for i in range(0,100):
        xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size= 0.22, random_state=i)
        j.fit(xtrain,ytrain)
        pred_train = j.predict(xtrain)
        pred_test= j.predict(xtest)

        print(f"For Model {j} At random state {i}, the training accuracy is: {r2_score(ytrain,pred_train)}")
        print(f"For Model {j} At random state {i}, the testing accuracy is: {r2_score(ytest,pred_test)}")
        print('\n')
# Out:
# For Model KNeighborsRegressor(n_neighbors=2) At random state 0, the training accuracy is: 0.7715290884879906
# For Model KNeighborsRegressor(n_neighbors=2) At random state 0, the testing accuracy is: 0.27379737037194585
#
#
# For Model KNeighborsRegressor(n_neighbors=2) At random state 1, the training accuracy is: 0.8046226272717824
# For Model KNeighborsRegressor(n_neighbors=2) At random state 1, the testing accuracy is: 0.11269782922822114
#
#
# For Model KNeighborsRegressor(n_neighbors=2) At random state 2, the training accuracy is: 0.766148577991153
# For Model KNeighborsRegressor(n_neighbors=2) At random state 2, the testing accuracy is: 0.10728979692105467
#
#
# For Model KNeighborsRegressor(n_neighbors=2) At random state 3, the training accuracy is: 0.8015348999935388
# For Model KNeighborsRegressor(n_neighbors=2) At random state 3, the testing accuracy is: -0.029848406335879485
#
#
# ...

# %% [markdown]
# As per above visualization we found model Random Forest Regressor is best at random state 67

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size= 0.22, random_state=67)
predrf_train = rf.predict(xtrain)
predrf_test= rf.predict(xtest)

print("Mean Squared error", mean_squared_error(ytest,predrf_test))
print("Mean Absolute Error", mean_absolute_error(ytest,predrf_test))
# Out:
# Mean Squared error 2929409.6437257575
# Mean Absolute Error 1044.6246599927852

# %%
print(r2_score(ytest,predrf_test))
# Out:
# 0.8786589497379009

# %% [markdown]
# # Using Grid Search CV Best Parameter

# %%
from sklearn.model_selection import GridSearchCV

model = RandomForestRegressor()
param_grid = {'n_estimators': [10,20,50,100],"max_features" : ["auto", "sqrt", "log2"],"min_samples_split": [2,4,8],"bootstrap": [True, False]}
xg_grid = GridSearchCV(estimator = model, param_grid = param_grid)
print(xg_grid)
xg_grid.fit(xtrain, ytrain)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 50, 100]})
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 50, 100]})

# %%
print(xg_grid.best_score_)
print(xg_grid.best_estimator_)
print(xg_grid.best_params_)
# Out:
# 0.498421127584446
# RandomForestRegressor(bootstrap=False, max_features='sqrt', n_estimators=50)
# {'bootstrap': False, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 50}

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size= 0.22, random_state=11)
RFR = RandomForestRegressor(n_estimators=50,bootstrap=False,max_features='sqrt', min_samples_split=2)
RFR.fit(xtrain,ytrain)
pred_train =RFR.predict(xtrain)
pred_test= RFR.predict(xtest)
print("Mean Squared error", mean_squared_error(ytest,pred_test))
print("Mean Absolute Error", mean_absolute_error(ytest,pred_test))
# Out:
# Mean Squared error 10947162.600386743
# Mean Absolute Error 2322.6099621212124

# %%
print(r2_score(ytest,pred_test))
# Out:
# 0.623683378243657

# %% [markdown]
# # Cross Validation of the Model

# %%
train_accuracy = r2_score(ytrain,pred_train)
test_accuracy =r2_score(ytest,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score =cross_val_score(RFR,X,y,cv=j)
    cv_mean = cv_score.mean()
    print(f"At cross val  {j} the cv score  is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross val  2 the cv score  is 0.13822938772515414 and accuracy score for training is 0.999861472808888 and accuracy for testing is 0.623683378243657
#
#
# At cross val  3 the cv score  is 0.19141282562679518 and accuracy score for training is 0.999861472808888 and accuracy for testing is 0.623683378243657
#
#
# At cross val  4 the cv score  is -0.015763405917417123 and accuracy score for training is 0.999861472808888 and accuracy for testing is 0.623683378243657
#
#
# At cross val  5 the cv score  is 0.21785407037554885 and accuracy score for training is 0.999861472808888 and accuracy for testing is 0.623683378243657
#
#
# At cross val  6 the cv score  is 0.06427024809612096 and accuracy score for training is 0.999861472808888 and accuracy for testing is 0.623683378243657
#
#
# At cross val  7 the cv score  is -0.06282764675312416 and accuracy score for training is 0.999861472808888 and accuracy for testing is 0.623683378243657
#
#
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(x= ytest, y =pred_test, color= "maroon")
plt.plot(ytest,ytest, color='b')
plt.xlabel('Actual Charges', fontsize= 14)
plt.ylabel("Predicted Charges", fontsize=14)
plt.show()

# %% [markdown]
# # Saving Model

# %%
import pickle
filename = 'flight.pkl'
pickle.dump(RFR,open(filename, 'wb'))

# %% [markdown]
# # Conclusion

# %%
loaded_model = pickle.load(open('flight.pkl', 'rb'))
result = loaded_model.score(xtest,ytest)
print(result)
# Out:
# 0.623683378243657

# %%
conclusion = pd.DataFrame([loaded_model.predict(xtest)[:],pred_test[:]],index=["Predicted", "Original"])

# %%
conclusion
# Out:
#                 0       1        2       3        4        5        6    \
# Predicted  10813.34  6488.1  12136.0  9864.5  15804.0  15348.0  9077.26
# Original   10813.34  6488.1  12136.0  9864.5  15804.0  15348.0  9077.26
#
#                7         8        9    ...       254      255       256  \
# Predicted  8831.96  20788.32  12677.4  ...  16824.24  9615.72  11000.02
# Original   8831.96  20788.32  12677.4  ...  16824.24  9615.72  11000.02
#
#                257       258       259       260       261       262       263
# Predicted  11222.4  16483.66  15992.18  12204.16  15960.52  18126.14  14089.04
# Original   11222.4  16483.66  15992.18  12204.16  15960.52  18126.14  14089.04
#
# [2 rows x 264 columns]
