# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Ques-1 Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
rank= []
name=[]
artist=[]
date=[]
views=[]

ra= driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[1]')
for r in ra:
    rank.append(r.text)
na= driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')
for n in na:
    name.append(n.text)
ar= driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')
for a in ar:
    artist.append(a.text)
    
dt= driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[5]')
for d in dt:
    date.append(d.text)
    
vw= driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')
for v in vw:
    views.append(v.text)

# %%
df= pd.DataFrame({'Rank':rank, "Name":name, "Artist":artist, "Date":date, "Views":views})
df.head(30)

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv.

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.bcci.tv/")

# %%
button = driver.find_element_by_xpath('/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
button.click()

# %%
title= []
series=[]
place=[]
date=[]
time=[]

ti = driver.find_elements_by_xpath('//span[@class="matchOrderText ng-binding ng-scope"]')
for i in ti:
    title.append(i.text)
    
se = driver.find_elements_by_xpath('//span[@class="ng-binding"]')
for j in se:
    series.append(j.text)

pl = driver.find_elements_by_xpath('//span[@class="ng-binding ng-scope"]')
for k in pl:
    place.append(k.text)
    
dt = driver.find_elements_by_xpath('//h5[@class="ng-binding"]')
for l in dt:
    date.append(l.text)

tm = driver.find_elements_by_xpath('//div[@class="match-card-right match-schedule "]')
for m in tm:
    time.append(m.text)

# %%
df = pd.DataFrame({'Title':title, 'Series':series, "Place":place, "Date":date, "Time":time})
df

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com.

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.guru99.com/")

# %%
sel_button = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a")
sel_button.click()
sel_ex= driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a/strong")
sel_ex.click()

# %%
name= []
desc= []

na= driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[1]')
for n in na:
    name.append(n.text)
    
dc= driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[2]')
for d in dc:
    desc.append(d.text)

# %%
df = pd.DataFrame({'Name':name, 'Description':desc})
df

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com.

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("http://statisticstimes.com/")

# %%
drop= driver.find_element_by_xpath("/html/body/div[2]/div[1]/div[2]/div[2]/button/i")
drop.click()
on= driver.find_element_by_xpath("/html/body/div[2]/div[1]/div[2]/div[2]/div/a[1]")
on.click()

# %%
st= driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
st.click()

# %%
rank= []
state= []
gsdp_18_19=[]
gsdp_19_20=[]
share=[]
gdp=[]

ran= driver.find_elements_by_xpath('//table[@class="display dataTable"]/tbody/tr/td[1]')
for r in ran:
    if (r.text==None):
        rank.append("--")
    else:
        rank.append(r.text)
    
st= driver.find_elements_by_xpath('//table[@class="display dataTable"]/tbody/tr/td[2]')
for s in st:
    if (s.text==None):
        state.append("--")
    else:
        state.append(s.text)
    
gs= driver.find_elements_by_xpath('//table[@class="display dataTable"]/tbody/tr/td[4]')
for g in gs:
    if (g.text==None):
        gsdp_18_19.append("--")
    else:
        gsdp_18_19.append(g.text)
        
gss= driver.find_elements_by_xpath('//table[@class="display dataTable"]/tbody/tr/td[3]')
for gg in gss:
    if (gg.text==None):
        gsdp_19_20.append("--")
    else:
        gsdp_19_20.append(gg.text)

sh= driver.find_elements_by_xpath('//table[@class="display dataTable"]/tbody/tr/td[5]')
for ss in sh:
    if (ss.text==None):
        share.append("--")
    else:
        share.append(ss.text)
        
gd= driver.find_elements_by_xpath('//table[@class="display dataTable"]/tbody/tr/td[6]')
for ggg in gd:
    if (ggg==None):
        gdp.append("--")
    else:
        gdp.append(ggg.text)

# %%
df = pd.DataFrame({'Rank':rank, 'State':state, "GSDP(18-19)":gsdp_18_19, "GSDP(19-20)":gsdp_19_20, "Share":share, "GDP":gdp})
df

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com.

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://github.com/")

# %%
drp= driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary")
drp.click()
tr_bu=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
tr_bu.click()

# %%
rep_title=[]
rep_des=[]
con_count=[]
lan=[]

rt= driver.find_elements_by_xpath('//span[@class="text-normal"]')
for z in rt:
    rep_title.append(z.text)
    
dc= driver.find_elements_by_xpath('//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for y in dc:
    if y.text is None:
        rep_des.append("--")
    else:
        rep_des.append(y.text)
    
ln= driver.find_elements_by_xpath('//span[@itemprop="programmingLanguage"]')
for x in ln:
    if x.text is None:
        lan.append("--")
    else:
        lan.append(x.text)

# %%
rep_des.insert(9,'--')
rep_des.insert(11,"--")
lan.insert(3,"--")
lan.insert(6,"--")
lan.insert(9,'--')

# %%
len(lan)

# %%
df= pd.DataFrame({"Repository_Title":rep_title, "Repository_Description":rep_des, "Language":lan})
df

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billiboard.com.

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https:/www.billboard.com/")

# %%
ch= driver.find_element_by_xpath('/html/body/div[3]/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a')
ch.click()

# %%
bt= driver.find_element_by_xpath("/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a")
bt.click()

# %%
name=[]
artist=[]
Last_rank=[]
Peak_rank=[]
Week_board=[]

# %%
na= driver.find_elements_by_xpath('//h3[@id="title-of-a-story"]')
for nn in na:
    name.append(nn.text)
name1= name[6:405:4]

# %%
ar = driver.find_elements_by_xpath('//li[@class="lrv-u-width-100p"]/ul/li/span')
for i in ar:
    artist.append(i.text)
artist1= artist[0:401:4]

# %%
lw= driver.find_elements_by_xpath('//li[@class="lrv-u-width-100p"]/ul/li/span')
for l in lw:
    Last_rank.append(l.text)
last1= Last_rank[1:401:4]

# %%
pw= driver.find_elements_by_xpath('//li[@class="lrv-u-width-100p"]/ul/li/span')
for p in pw:
    Peak_rank.append(p.text)
peak1= Peak_rank[2:401:4]

# %%
wb= driver.find_elements_by_xpath('//li[@class="lrv-u-width-100p"]/ul/li/span')
for ww in wb:
    Week_board.append(ww.text)
week1= Week_board[3:401:4]

# %%
df=pd.DataFrame({'Song_Name':name1, 'Artist_Name':artist1, 'Last_Week_Rank':last1, 'Peak_Rank':peak1,"Week_Board":week1})
df
# Out:
#                                  Song_Name  \
# 0                                As It Was
# 1                              First Class
# 2                               Wait For U
# 3                          About Damn Time
# 4   Running Up That Hill (A Deal With God)
# ..                                     ...
# 95                                  Plan B
# 96                             Tomorrow Me
# 97                                  Potion
# 98                               New Truck
# 99              Wrapped Around Your Finger
#
#                              Artist_Name Last_Week_Rank Peak_Rank Week_Board
# 0                           Harry Styles              1         1         11
# 1                            Jack Harlow              2         1         10
# 2          Future Featuring Drake & Tems              3         1          7
# 3                                  Lizzo              5         4          9
# ...

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com.

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.naukri.com/hr-recruiters-consultants')

# %%
search_des= driver.find_element_by_class_name("sugInp")
search_des.send_keys('Data Scientist')

# %%
searc_button= driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button")
searc_button.click()

# %%
name=[]
des=[]
company=[]
skill=[]
location=[]

# %%
nm= driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')
for n in nm:
    name.append(n.text)

# %%
ds= driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
for d in ds:
    des.append(d.text)

# %%
com= driver.find_elements_by_xpath('//i[@class="cmpIcn"]')
for c in com:
    company.append(c.text)
comm1= company[1:101:2]

# %%
sk= driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
for s in sk:
    skill.append(s.text)

# %%
try:
    loc= driver.find_elements_by_xpath('//small[@class="ellipsis"]')
    for l in loc:
        location.append(l.text)
except NoSuchElementException as e:
    location.append("--")

# %%
location.insert(34,'--')

# %%
df=pd.DataFrame({'Recruiter_Name':name, 'Designation':des, 'Company':comm1, 'Skill':skill,"Location":location})
df
# Out:
#                                   Recruiter_Name  \
# 0                                      Tanushree
# 1                                  sashi bhushan
# 2                                         Bitapi
# 3                                 Gajendra Singh
# 4                              Sadashiv Kulkarni
# 5                                    Invelopment
# 6                              Anjali Srivastava
# 7                                     Helly Vyas
# 8                                   Ashish Verma
# 9                             Balaji Prabhakaran
# 10                                 Shiva Kumar N
# 11                              Bhuwneshari Devi
# 12                                    HS Sandesh
# 13                               Anoop Somarajan
# 14                                   Datafoundry
# 15                               A Valsa Florina
# 16                                 Kalaivani M V
# 17                                    Prashant K
# ...

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
name=[]
year_span=[]
genre=[]
run_time=[]
rating=[]
votes=[]

# %%
na = driver.find_elements_by_xpath('//div[@class="lister-item-content"]/a')
for n in na:
    name.append(n.text)
name1=name[202:302]

# %%
yr = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/span[2]')
for y in yr:
    year_span.append(y.text)
years1=year_span[101:201]

# %%
ge = driver.find_elements_by_xpath('//p[@class="text-muted text-small"]/span[5]')
for g in ge:
    genre.append(g.text)

# %%
ru = driver.find_elements_by_xpath('//p[@class="text-muted text-small"]/span[3]')
for r in ru:
    run_time.append(r.text)
run1=run_time[0:100]

# %%
ra = driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]/span[2]')
for rt in ra:
    rating.append(rt.text)

# %%
vo = driver.find_elements_by_xpath('//p[@class="text-muted text-small"]/span[2]')
for v in vo:
    votes.append(v.text)
votes1= votes[201:401:2]

# %%
df= pd.DataFrame({"Movie_Name":name1, "Years_Span":years1, "Genre":genre, "Run_Time":run1, "Rating":rating, "Votes":votes1})
df
# Out:
#                                         Movie_Name   Years_Span  \
# 0                   1. Game of Thrones (2011–2019)     (2016– )
# 1                      2. Stranger Things (2016– )  (2010–2022)
# 2                  3. The Walking Dead (2010–2022)  (2017–2020)
# 3                    4. 13 Reasons Why (2017–2020)  (2014–2020)
# 4                           5. The 100 (2014–2020)  (2013–2019)
# ..                                             ...          ...
# 95                           96. Reign (2013–2017)  (2017–2019)
# 96  97. A Series of Unfortunate Events (2017–2019)  (2005–2020)
# 97                  98. Criminal Minds (2005–2020)  (2015–2019)
# 98           99. Scream: The TV Series (2015–2019)       (2018)
# 99          100. The Haunting of Hill House (2018)  (2011–2019)
#
#                        Genre Run_Time Rating      Votes
# 0   Action, Adventure, Drama   57 min    9.2  1,998,743
# 1     Drama, Fantasy, Horror   51 min    8.7  1,047,627
# ...

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories.

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://archive.ics.uci.edu/")

# %%
view= driver.find_element_by_xpath("/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b")
view.click()

# %%
dataset=[]
dtype=[]
task=[]
at_name=[]
num_ins=[]
num_at=[]
years=[]

# %%
try:
    dt= driver.find_elements_by_xpath('//p[@class="normal"]/b')
    for d in dt:
        dataset.append(d.text)
except NoSuchElementException as e:
    dt= driver.find_elements_by_xpath('//p[@class="normal"]/b')
    dataset.append("--")

# %%
try:
    da= driver.find_elements_by_xpath('//p[@class="normal"]')
    for dd in da:
        dtype.append(dd.text)
except NoSuchElementException as e:
    dtype.append("--")

# %%
dtype1=dtype[11:4368:7]
task=dtype[12:4368:7]
at_name=dtype[13:4368:7]
num_ins=dtype[14:4369:7]
num_at=dtype[15:4370:7]
years=dtype[16:4371:7]

# %%
df= pd.DataFrame({"DataSet_Name":dataset,"Data_Type":dtype1,"Default_Task":task,"Attirbute_Type":at_name,"No. of Instance":num_ins, "No. of Attributes":num_at, "Years":years})
df
# Out:
#                                           DataSet_Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
# 622  Browse Through:\nDefault Task\nClassification ...
#
#                       Data_Type  \
# 0                 Multivariate
# 1                 Multivariate
# 2                 Multivariate
# 3
# 4                 Multivariate
# ..                          ...
# 618               Multivariate
# 619
# 620  Multivariate, Time-Series
# ...

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare - compare/
# You have to

# %%
driver = webdriver.Chrome(r"C:\Users\NITIN GUPTA\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
book=[]
author=[]
sold=[]
publish=[]
genre=[]

# %%
nm= driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
for n in nm:
    book.append(n.text)
book1= book[0:100]
    
au= driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[3]')
for a in au:
    author.append(a.text)
so= driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
for s in so:
    sold.append(s.text)
pu= driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
for p in pu:
    publish.append(p.text)
ge= driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[6]')
for g in ge:
    genre.append(g.text)

# %%
print(len(book1),len(author),len(sold),len(publish),len(genre))
# Out:
# 100 100 100 100 100

# %%
df= pd.DataFrame({"Book_Name":book1, "Author":author, "Book_Sold":sold, "Publisher_Name":publish, "Genre":genre})
df
# Out:
#                                             Book_Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#     Book_Sold Publisher_Name                        Genre
# ...
